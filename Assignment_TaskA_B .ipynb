# %% [markdown]
# # FIT 5148: Assignment 1
# ## Task A. MongoDB Data Model

# %% [markdown]
# ## The Data Model
# >- The following representation is the sample data model designed for storing data in two separate collections, as follows,
#
# ### 1. `hotspot_historic`
# `collection_name: hotpost_historic`
#
# **meta-data**: collection used to store data coming from file hotspot_historic.csv
#
#
#
# `<model_design>: `
#
#
#
#
#
#
#
#             `{
#             '_id': 123
#             location: {
#                       type: "Point",
#                       coordinates: [<long>, <lat>]
#                        },
#             'datetime':<dummy_value3>,
#             'confidence':<dummy_value4>,
#             'date':<dummy_value5>,
#             'surface_temperature_celcius':<dummy_value6>
#             },
#
#             {
#             '_id': 345
#             location: {
#                       type: "Point",
#                       coordinates: [<long>, <lat>]
#                        },
#             'datetime':<dummy_value3>,
#             'confidence':<dummy_value4>,
#             'date':<dummy_value5>,
#             'surface_temperature_celcius':<dummy_value6>
#             }
#             ...
#
#             ...
#             {
#             '_id': 999
#             location: {
#                       type: "Point",
#                       coordinates: [<long>, <lat>]
#                        },
#             'datetime':<dummy_value3>,
#             'confidence':<dummy_value4>,
#             'date':<dummy_value5>,
#             'surface_temperature_celcius':<dummy_value6>
#             }`
#
# ### 1.1 sample `hotspot_historic` data
# `
# {'_id': ObjectId('5cc6820c934369640f86bf8f'),
#  'confidence': 78,
#  'date': datetime.datetime(2017, 12, 27, 0, 0),
#  'datetime': datetime.datetime(2017, 12, 27, 4, 16, 51),
#  'location': {'coordinates': [-37.966, 145.051], 'type': 'Point'},
#  'surface_temperature': 68}
# `
#
#
# ### 2. `climate_hotspot`
# `collection_name: climate_hotspot`
#
# **meta-data**: collection used to store data coming from file climate_historic.csv
#
#
#
# `<model_design>: `
#
#
#
#             `{
#             'date':{
#                     'station'::<dummy_value1>,
#                     'date':<dummy_value1>,
#                     'air_temperature_celcius':<dummy_value1>,
#                     'relative_humidity':<dummy_value1>,
#                     'windspeed_knots':<dummy_value1>,
#                     'max_wind_speed':<dummy_value1>,
#                     'precipitation ':<dummy_value1>,
#                     'hotspot_data': ['<list of ids in hotspot_historic collection>']
#                     }
#
#             }`

# %% [markdown]
# ### 2.1 sample `climate_hotspot` data
#
# `
# {'_id': ObjectId('5cc68217934369640f86ca3b'),`
#
# ` 'air_temperature': 20,`
#
# ` 'date': datetime.datetime(2017, 3, 6, 0, 0),`
#
#  `'hotspot_data': [{'_id': ObjectId('5cc6820d934369640f86c9f9')},
#                   {'_id': ObjectId('5cc6820d934369640f86c9fa')}], `
#
#
# ` 'max_wind_speed': 21.0,`
#
# ` 'precipitation': ' 0.00I',`
#
# ` 'relative_humidity': 52.9,`
#
# ` 'station': 948701,`
#
# ` 'windspeed_knots': 17.0}`

# %% [markdown]
# ## Justification

# %% [markdown]
# ### Model selection
# - The data model for Hotspot historic and Climate historic is based on the **reference** data model.
# - Since there can be multiple data-sets of hotspot historic is found for one date value in climate data, **hotspot** data is referenced in **climate** data collection.
# - To avoid lengthy document size in single collection, reference based model approach is used.
#
# ### Hotspot historic model
# - In the Hotspot historic data the **Latitude and Longitude** were combined into lists and refered as points as standard mongoDB spatial data notation.
# - Rest of the variables in Hotspot Historic data are straight forward as there is no need to embed the data model.
#
# ### Climate hotspot model
# - In the Climate Historic the variables are embeded into the **date** key such that for each unique date there are variables from climate historic data refering to the pirticular date and the **IDs** of the Hotspot Historic data falling on the **same** date for the sake of referencing.
#
# ### Ease of query
# - For the further queries in **Task B** this model was found most appropriate as there was no need to **unwind** the data while running the queries.
# - Data is stored in these model in such a way that query retrieval can be done using quite simple queries, avoiding nested and complicated queries.

# %% [markdown]
# # Task B. Querying MongoDB using PyMongo
# ## Task B.1
# ### Reading data

# %%
# Importing the required libraries
import csv  # to read the csv files
from pymongo import MongoClient, ASCENDING, DESCENDING  #The pymongo libraries for accessing the database
import json  # to dump files into the json format
import datetime   # to convert string object to datetime object

# %%
#function to read the csv file and return the header and data
def read_csv(file_name):
    header = []
    data = []
    with open(file_name, 'r') as f:
        reader = csv.reader(f)
        row_count = 0
        
        for row in reader:
            if(row_count == 0):
                header.extend(row)
            else:
                data.append(row)
            row_count += 1
    
    return header, data
header_list_climate, data_climate = read_csv('climate_historic.csv')# read the Climate data
header_list_hotspot, data_hotspot = read_csv('hotspot_historic.csv')# read the Hotspot data
print("Header fields for hotspot_historic file are \n{}\n".format(header_list_hotspot))
print("Header fields for climate_historic file are \n{}".format(header_list_climate))
# Out:
# Header fields for hotspot_historic file are
# ['latitude', 'longitude', 'datetime', 'confidence', 'date', 'surface_temperature_celcius']
#
# Header fields for climate_historic file are
# ['station', 'date', 'air_temperature_celcius', 'relative_humidity', 'windspeed_knots', 'max_wind_speed', 'precipitation ']

# %% [markdown]
# ### Connection to database

# %%
connection = MongoClient()  # Creating a mongoDb connection with localhost and default Port
db = connection['fit5148_assignment_db']  # Creating a database

# %% [markdown]
# ## Creation & indexing `hotspot_historic` collection

# %%
hotspot_coll = db['hotspot_historic']  #Create a collection Of hotspot historic data

# %% [markdown]
# ### Creating Indexes for optimizing the data processing

# %%
hotspot_coll.create_index('confidence',unique = False)
hotspot_coll.create_index('surface_temperature', unique = False)
# Out:
# 'surface_temperature_1'

# %%
# collection index info
hotspot_coll.index_information()
# Out:
# {'_id_': {'key': [('_id', 1)],
#   'ns': 'fit5148_assignment_db.hotspot_historic',
#   'v': 2},
#  'confidence_1': {'key': [('confidence', 1)],
#   'ns': 'fit5148_assignment_db.hotspot_historic',
#   'v': 2},
#  'surface_temperature_1': {'key': [('surface_temperature', 1)],
#   'ns': 'fit5148_assignment_db.hotspot_historic',
#   'v': 2}}

# %% [markdown]
# ## Populating  `hotspot_historic` collection

# %%
hotspot_list = []  #created a empty list
for d in data_hotspot:  # accessing each value in hotspot data 

    hotspot_dict = {}  #create a empty dictionary everytime the loop starts 
    
    ###Append the data into the dictionary column wise
    hotspot_dict['location'] = {'type':"Point", 'coordinates':[float(d[0]),float(d[1])]}
    hotspot_dict['datetime'] = datetime.datetime.strptime(d[2], '%Y-%m-%dT%H:%M:%S')
    hotspot_dict['confidence'] = int(d[3])
    hotspot_dict['date'] = datetime.datetime.strptime(d[4], '%d/%m/%Y')
    hotspot_dict['surface_temperature'] = int(d[5])
    
    ## Finally append the dictionary into the list created above this will create a list of dictionaries (JSON)
    hotspot_list.append(hotspot_dict)

# %% [markdown]
# ### Bulk insert

# %%
#bulk insert documents into hotspot collection
hotspot_coll.insert_many(hotspot_list, ordered = False)  # Inserting all the values in Hotspot dictionary into the dataframe

# %% [markdown]
# ### Utility function
# * Below functions are utility functions, used to transform data in readable format for query operations.

# %%
# Function to convert string date object into the datetime object
def format_date(date):
    return datetime.datetime.strptime(date, '%d/%m/%Y')

# %%
def to_dict(cursor):   #A function to return a dictionary from the MongoDb cursor 
    _list = [] #empty list
    for c in cursor:  # for each value in cursor
        _list.append(c)  # append the value into list
    if _list:    # if list is not null
        return _list if len(_list)>1 else _list[0] #return the list if length is >1 else return 0
    else:
        return {}  # return an empty dictionary

# %%
# returns hotspot datarows corresponding to a particular date value parameter
def get_hotspotdata_bydate(date):
    _list = []  #emty list
    cursor = hotspot_coll.find({'date':datetime.datetime.strptime(date, '%d/%m/%Y')},{'_id':1})  # query for finding the required date in the hotspot data
    for c in cursor:     # for each value in cursor returned by MongoDb query
        _list.append(c)   #append the value to the list
    return _list              #return the list

# %% [markdown]
# ## Creation `climate_hotspot` collection

# %%
climate_coll = db['climate_hotspot']   #Create a climate historic collection

# %% [markdown]
# ## Populating `climate_hotspot` collection

# %%
climate_list = []  #empty list
for d in data_climate:    #for each in climate data
    climate_dict = {}           #Empty dictionary for every iteration
    
    ###Append the data into the dictionary column wise
    climate_dict['station'] = int(d[0])
    climate_dict['date'] = datetime.datetime.strptime(d[1], '%d/%m/%Y')
    climate_dict['air_temperature'] = int(d[2])
    climate_dict['relative_humidity'] = float(d[3])
    climate_dict['windspeed_knots'] = float(d[4])
    climate_dict['max_wind_speed'] = float(d[5])
    climate_dict['precipitation'] = d[6]
    climate_dict['hotspot_data'] = get_hotspotdata_bydate(d[1])
    
    # finally append into the list to make a list of dictionaries to insert into the DB collection
    climate_list.append(climate_dict)

# %%
#bulk insert
climate_coll.insert_many(climate_list, ordered = False)

# %% [markdown]
# ## Task B.2
# ### Queries

# %% [markdown]
# >- Find climate data on 10th December 2017

# %%
# Find climate data on 10th December 2017.
climate_dt = climate_coll.find({'date':format_date('10/12/2017')},{'hotspot_data':0, '_id':0}) #searching for a exact match in date

# %%
for m in climate_dt:
    print(m)
# Out:
# {'station': 948702, 'date': datetime.datetime(2017, 12, 10, 0, 0), 'max_wind_speed': 14.0, 'precipitation': ' 0.00I', 'windspeed_knots': 7.3, 'relative_humidity': 53.5, 'air_temperature': 17}

# %% [markdown]
# >- Find the latitude, longitude, surface temperature (°C), and confidence when
# the surface temperature (°C) was between 65 °C and 100 °C.

# %%
#Find the latitude, longitude, surface temperature(°C), and confidence when the 
#surface temperature(°C) was between 65 °C and 100°C
sur_tmp_range = hotspot_coll.find({'surface_temperature':{'$gte':65, '$lte':100}},{'_id':0, 'date':0, 'datetime':0})  #finding data with surface temp between 65 and 100

# %%
for m in sur_tmp_range:
    print(m)
# Out:
# {'confidence': 100, 'location': {'coordinates': [-37.642, 149.263], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 87, 'location': {'coordinates': [-37.862, 144.175], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 90, 'location': {'coordinates': [-37.331, 143.122], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 88, 'location': {'coordinates': [-37.46, 148.102], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 100, 'location': {'coordinates': [-37.446, 148.102], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 100, 'location': {'coordinates': [-37.396, 148.086], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-38.3998, 147.064], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-38.4792, 146.3081], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-36.5661, 142.2956], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-35.4666, 142.0749], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-36.7218, 141.6411], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-36.4143, 143.272], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-37.876, 143.7804], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-36.2618, 141.8783], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-37.0959, 143.8206], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-34.9023, 142.0557], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-36.73, 143.935], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-36.0295, 143.6409], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-38.1561, 143.7846], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-35.7642, 143.3321], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-36.1441, 145.2221], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-37.88, 143.7233], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 84, 'location': {'coordinates': [-37.5816, 148.5862], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 77, 'location': {'coordinates': [-37.8062, 143.3598], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-36.9902, 141.879], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-37.745, 142.993], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-34.3943, 141.7567], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 88, 'location': {'coordinates': [-37.7746, 148.3673], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-37.4471, 147.6331], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-37.4449, 147.6594], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-35.4255, 143.6306], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-36.1556, 141.5904], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-35.7647, 142.0858], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 82, 'location': {'coordinates': [-37.8973, 143.4754], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 89, 'location': {'coordinates': [-34.3654, 141.543], 'type': 'Point'}, 'surface_temperature': 65}
# {'confidence': 90, 'location': {'coordinates': [-37.624, 149.314], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 73, 'location': {'coordinates': [-37.444, 148.101], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-36.7032, 144.0992], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 85, 'location': {'coordinates': [-36.5023, 143.6038], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 89, 'location': {'coordinates': [-36.5116, 144.562], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 80, 'location': {'coordinates': [-36.1559, 141.8102], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-37.6267, 142.9993], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-36.6828, 144.784], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 89, 'location': {'coordinates': [-37.4843, 143.0592], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 84, 'location': {'coordinates': [-38.0423, 146.4048], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 89, 'location': {'coordinates': [-37.2609, 141.7999], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 78, 'location': {'coordinates': [-35.9326, 141.958], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-35.1949, 141.0622], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 89, 'location': {'coordinates': [-35.8071, 142.7318], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-37.8185, 142.5609], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-36.1462, 145.2096], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-36.8867, 142.1873], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-36.5399, 144.678], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-36.7165, 142.6155], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 76, 'location': {'coordinates': [-37.7966, 142.3196], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-36.6384, 142.4075], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-37.7835, 148.4138], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 85, 'location': {'coordinates': [-36.111, 145.124], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-36.1615, 141.8728], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 85, 'location': {'coordinates': [-35.4533, 143.2029], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 89, 'location': {'coordinates': [-37.7446, 143.4085], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-35.7657, 142.0906], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 90, 'location': {'coordinates': [-37.4523, 147.0175], 'type': 'Point'}, 'surface_temperature': 66}
# {'confidence': 86, 'location': {'coordinates': [-35.543, 143.316], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 92, 'location': {'coordinates': [-36.098, 143.74], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.4325, 144.3142], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-38.0372, 146.0616], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.2911, 141.1664], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.3435, 141.5513], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.094, 145.7646], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.1303, 146.3606], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.7101, 142.3865], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-37.7756, 143.1388], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-37.1349, 141.9491], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.429, 141.5759], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.8835, 142.2098], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.7903, 141.618], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.782, 141.8851], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.2857, 141.3467], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.5532, 142.5349], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-37.5788, 148.592], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-36.0387, 145.6787], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-35.4033, 143.267], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 79, 'location': {'coordinates': [-36.883, 142.1637], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 90, 'location': {'coordinates': [-34.357, 141.5361], 'type': 'Point'}, 'surface_temperature': 67}
# {'confidence': 78, 'location': {'coordinates': [-37.966, 145.051], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-37.247, 141.278], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.3774, 143.7079], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.7801, 142.7151], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.7746, 146.6642], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 90, 'location': {'coordinates': [-35.6871, 143.5235], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 84, 'location': {'coordinates': [-37.8323, 147.2232], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.4168, 141.6939], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-35.6138, 143.8666], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.5061, 144.5675], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.3635, 142.2809], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.7751, 145.1696], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-37.6397, 142.5968], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 77, 'location': {'coordinates': [-36.7101, 142.981], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-37.7171, 142.9505], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-37.0782, 145.3625], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.7651, 143.5801], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.3487, 145.5315], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 90, 'location': {'coordinates': [-36.5568, 144.0538], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-37.6171, 142.9426], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-36.4449, 140.9836], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 86, 'location': {'coordinates': [-37.5814, 148.5777], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-37.3803, 145.611], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 64, 'location': {'coordinates': [-36.6281, 142.4349], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 91, 'location': {'coordinates': [-38.0674, 142.965], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 90, 'location': {'coordinates': [-36.9939, 148.2244], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 80, 'location': {'coordinates': [-37.0055, 148.1582], 'type': 'Point'}, 'surface_temperature': 68}
# {'confidence': 89, 'location': {'coordinates': [-36.94, 143.281], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 64, 'location': {'coordinates': [-37.45, 148.126], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-37.8644, 143.4263], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-36.7685, 142.7134], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-36.5541, 144.1321], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-35.6819, 143.5275], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-36.3153, 140.9789], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-36.6564, 142.8615], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-36.3961, 140.9781], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 92, 'location': {'coordinates': [-36.7593, 142.895], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-37.6964, 142.8583], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-36.2637, 145.3649], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-36.6892, 145.2775], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-36.1748, 145.7582], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-37.4611, 144.9371], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-35.6453, 142.387], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-35.2363, 143.0004], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 92, 'location': {'coordinates': [-36.6334, 142.2244], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 91, 'location': {'coordinates': [-36.031, 145.6824], 'type': 'Point'}, 'surface_temperature': 69}
# {'confidence': 92, 'location': {'coordinates': [-37.95, 142.366], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.9396, 143.1462], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.3207, 140.9737], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-37.4463, 142.7829], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.803, 142.9261], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.882, 142.7108], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 87, 'location': {'coordinates': [-37.9091, 143.5105], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-37.9284, 143.108], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-37.6498, 142.5997], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.5828, 144.5775], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.2652, 145.3769], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.1924, 143.1716], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.9364, 143.4996], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.0749, 143.4058], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-37.4033, 143.6884], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-37.2063, 147.4713], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-37.2082, 147.4368], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-36.0157, 145.9414], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-38.0715, 142.9591], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 92, 'location': {'coordinates': [-37.6625, 144.287], 'type': 'Point'}, 'surface_temperature': 70}
# {'confidence': 100, 'location': {'coordinates': [-36.282, 146.157], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 100, 'location': {'coordinates': [-37.634, 149.237], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 92, 'location': {'coordinates': [-38.2391, 142.82], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 92, 'location': {'coordinates': [-37.7889, 143.1324], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 92, 'location': {'coordinates': [-36.663, 142.8567], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 87, 'location': {'coordinates': [-38.0148, 146.5413], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 92, 'location': {'coordinates': [-36.1346, 145.2196], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 92, 'location': {'coordinates': [-36.0714, 145.7665], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 92, 'location': {'coordinates': [-36.5586, 144.0423], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 92, 'location': {'coordinates': [-36.1367, 145.2071], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 93, 'location': {'coordinates': [-36.6823, 142.5024], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 81, 'location': {'coordinates': [-36.0844, 141.4934], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 92, 'location': {'coordinates': [-37.8161, 142.9286], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 66, 'location': {'coordinates': [-36.6299, 142.4234], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 92, 'location': {'coordinates': [-36.4557, 142.2434], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 84, 'location': {'coordinates': [-37.0193, 148.1459], 'type': 'Point'}, 'surface_temperature': 71}
# {'confidence': 61, 'location': {'coordinates': [-37.562, 148.05], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.2306, 143.6408], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.6657, 143.1675], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-37.5135, 142.7238], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.6942, 143.8021], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 70, 'location': {'coordinates': [-36.9303, 143.1034], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.9111, 142.692], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-37.769, 147.94], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.1964, 144.5217], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.5871, 144.4958], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-37.9157, 143.3544], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.8879, 141.6647], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.663, 141.3038], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.1941, 143.1604], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-36.5243, 142.0839], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-37.5888, 148.5949], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 86, 'location': {'coordinates': [-36.6986, 142.7259], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-37.3165, 147.4932], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-37.0769, 141.042], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-37.7465, 143.3806], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-37.3046, 143.5448], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-34.3539, 141.5547], 'type': 'Point'}, 'surface_temperature': 72}
# {'confidence': 93, 'location': {'coordinates': [-37.875, 142.51], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-38.057, 144.211], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-37.945, 144.354], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-37.4984, 142.9739], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-37.4671, 145.9962], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 94, 'location': {'coordinates': [-37.6982, 143.0549], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 88, 'location': {'coordinates': [-38.0132, 146.5269], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-36.4046, 141.1534], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-36.388, 141.8309], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 94, 'location': {'coordinates': [-37.7274, 142.9536], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-38.1693, 143.0466], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 94, 'location': {'coordinates': [-38.1224, 143.7553], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 94, 'location': {'coordinates': [-37.7236, 142.947], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-36.4899, 142.2805], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-36.91, 141.0704], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-36.8238, 143.5724], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-35.0616, 141.4417], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 94, 'location': {'coordinates': [-36.3313, 141.0017], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-36.4489, 144.7685], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 93, 'location': {'coordinates': [-36.8099, 142.728], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 71, 'location': {'coordinates': [-37.522, 143.3874], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 94, 'location': {'coordinates': [-37.2284, 147.9187], 'type': 'Point'}, 'surface_temperature': 73}
# {'confidence': 94, 'location': {'coordinates': [-38.049, 146.0513], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 94, 'location': {'coordinates': [-36.2775, 146.1026], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 94, 'location': {'coordinates': [-37.4357, 142.7813], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 94, 'location': {'coordinates': [-37.7609, 143.1633], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 94, 'location': {'coordinates': [-36.2121, 144.6885], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 88, 'location': {'coordinates': [-36.1546, 141.8146], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 94, 'location': {'coordinates': [-36.3966, 141.406], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 67, 'location': {'coordinates': [-37.34, 149.3668], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 94, 'location': {'coordinates': [-36.7806, 141.5597], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 94, 'location': {'coordinates': [-36.7152, 141.3853], 'type': 'Point'}, 'surface_temperature': 74}
# {'confidence': 95, 'location': {'coordinates': [-37.613, 149.305], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 94, 'location': {'coordinates': [-36.0828, 145.873], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 94, 'location': {'coordinates': [-36.4179, 144.2924], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 94, 'location': {'coordinates': [-36.092, 141.7306], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 94, 'location': {'coordinates': [-36.2933, 141.36], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 94, 'location': {'coordinates': [-36.4816, 141.6635], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 95, 'location': {'coordinates': [-35.0706, 141.4435], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 95, 'location': {'coordinates': [-37.8906, 146.2035], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 94, 'location': {'coordinates': [-37.5812, 142.7374], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 95, 'location': {'coordinates': [-37.4028, 143.6932], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 95, 'location': {'coordinates': [-37.7805, 143.5003], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 95, 'location': {'coordinates': [-36.9959, 148.2118], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 94, 'location': {'coordinates': [-34.3555, 141.5495], 'type': 'Point'}, 'surface_temperature': 75}
# {'confidence': 95, 'location': {'coordinates': [-37.618, 149.281], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 86, 'location': {'coordinates': [-37.436, 148.088], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.0396, 141.7183], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-37.6854, 143.4543], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.0885, 145.0359], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-37.9509, 143.9599], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.7187, 143.805], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.6537, 143.8781], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-38.1987, 147.0666], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.3014, 143.203], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.6995, 142.978], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.8681, 143.5186], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.1418, 144.0261], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-37.224, 147.4347], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 90, 'location': {'coordinates': [-36.1104, 145.9829], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-37.3158, 147.4986], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-37.4323, 147.6583], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 90, 'location': {'coordinates': [-36.1122, 142.1491], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.4312, 141.2064], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 95, 'location': {'coordinates': [-36.8009, 142.7259], 'type': 'Point'}, 'surface_temperature': 76}
# {'confidence': 96, 'location': {'coordinates': [-37.475, 143.365], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 96, 'location': {'coordinates': [-38.127, 143.82], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 68, 'location': {'coordinates': [-37.452, 148.115], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 96, 'location': {'coordinates': [-36.3387, 141.7542], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 96, 'location': {'coordinates': [-36.3402, 141.7429], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-36.3254, 144.3638], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 96, 'location': {'coordinates': [-36.8094, 142.8885], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-36.6139, 143.501], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 83, 'location': {'coordinates': [-36.3195, 146.0601], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-36.7128, 142.3717], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-36.738, 142.1177], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-36.5199, 144.7311], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-36.3823, 141.3146], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-37.9152, 145.8808], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-37.8247, 143.6243], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 96, 'location': {'coordinates': [-37.7542, 142.9949], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-37.8072, 145.9738], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 95, 'location': {'coordinates': [-37.8774, 145.8213], 'type': 'Point'}, 'surface_temperature': 77}
# {'confidence': 62, 'location': {'coordinates': [-37.379, 148.132], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-36.1002, 142.3405], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-36.8359, 146.6448], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-37.253, 144.3681], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 90, 'location': {'coordinates': [-36.8616, 142.8025], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 84, 'location': {'coordinates': [-37.3656, 141.3903], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-38.0866, 143.9534], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-36.3438, 141.5832], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-36.3193, 145.9162], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-38.0933, 143.9824], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-37.8429, 147.2691], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 86, 'location': {'coordinates': [-37.6775, 148.5131], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-36.5847, 145.1968], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-37.7935, 143.1606], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-36.1898, 145.0922], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 84, 'location': {'coordinates': [-36.7531, 141.3253], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-36.9498, 142.2012], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-37.222, 147.4689], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 83, 'location': {'coordinates': [-37.803, 142.3151], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-36.1955, 145.914], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-36.6006, 141.9657], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 96, 'location': {'coordinates': [-37.3704, 145.8942], 'type': 'Point'}, 'surface_temperature': 78}
# {'confidence': 100, 'location': {'coordinates': [-37.401, 148.067], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 96, 'location': {'coordinates': [-36.2842, 141.1741], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 96, 'location': {'coordinates': [-36.0594, 141.5907], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 96, 'location': {'coordinates': [-36.6787, 144.8042], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 96, 'location': {'coordinates': [-36.5987, 144.4995], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 96, 'location': {'coordinates': [-36.8298, 143.4483], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 84, 'location': {'coordinates': [-36.7432, 141.3296], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 97, 'location': {'coordinates': [-36.1067, 143.7948], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 96, 'location': {'coordinates': [-36.1518, 144.0233], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 97, 'location': {'coordinates': [-36.1925, 145.93], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 96, 'location': {'coordinates': [-37.6622, 142.1001], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 96, 'location': {'coordinates': [-34.3554, 141.5413], 'type': 'Point'}, 'surface_temperature': 79}
# {'confidence': 97, 'location': {'coordinates': [-37.61, 149.307], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-37.69, 143.605], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-36.369, 143.7132], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-36.6224, 143.5092], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-36.2206, 144.6856], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-36.7787, 141.4449], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-37.0669, 141.0556], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-36.8158, 142.6229], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 91, 'location': {'coordinates': [-36.4612, 144.7775], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-36.601, 144.6378], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 84, 'location': {'coordinates': [-37.7587, 142.8521], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 66, 'location': {'coordinates': [-37.3493, 149.3691], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-37.0924, 141.897], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-37.9452, 143.5834], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-37.0155, 148.1432], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-37.6572, 142.0703], 'type': 'Point'}, 'surface_temperature': 80}
# {'confidence': 97, 'location': {'coordinates': [-36.4169, 144.2994], 'type': 'Point'}, 'surface_temperature': 81}
# {'confidence': 97, 'location': {'coordinates': [-36.4211, 141.6875], 'type': 'Point'}, 'surface_temperature': 81}
# {'confidence': 97, 'location': {'coordinates': [-37.4885, 142.0658], 'type': 'Point'}, 'surface_temperature': 81}
# {'confidence': 97, 'location': {'coordinates': [-36.6527, 142.7392], 'type': 'Point'}, 'surface_temperature': 81}
# {'confidence': 97, 'location': {'coordinates': [-36.4538, 144.763], 'type': 'Point'}, 'surface_temperature': 81}
# {'confidence': 97, 'location': {'coordinates': [-37.7617, 143.081], 'type': 'Point'}, 'surface_temperature': 81}
# {'confidence': 92, 'location': {'coordinates': [-36.5989, 141.9771], 'type': 'Point'}, 'surface_temperature': 81}
# {'confidence': 97, 'location': {'coordinates': [-37.9247, 142.8999], 'type': 'Point'}, 'surface_temperature': 81}
# {'confidence': 97, 'location': {'coordinates': [-35.0805, 142.4642], 'type': 'Point'}, 'surface_temperature': 81}
# {'confidence': 58, 'location': {'coordinates': [-37.379, 148.126], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-37.9085, 141.1038], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-38.2375, 142.8363], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-36.0652, 146.0764], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-37.758, 143.179], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-38.0509, 143.9423], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-36.5921, 144.4905], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-36.9329, 143.7796], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-36.2948, 141.3486], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-37.618, 143.0013], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-36.095, 141.7699], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-37.7509, 143.4023], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-34.3526, 141.6458], 'type': 'Point'}, 'surface_temperature': 82}
# {'confidence': 98, 'location': {'coordinates': [-37.605, 149.302], 'type': 'Point'}, 'surface_temperature': 83}
# {'confidence': 98, 'location': {'coordinates': [-38.2853, 145.9519], 'type': 'Point'}, 'surface_temperature': 83}
# {'confidence': 98, 'location': {'coordinates': [-35.2381, 142.994], 'type': 'Point'}, 'surface_temperature': 83}
# {'confidence': 93, 'location': {'coordinates': [-37.6439, 142.913], 'type': 'Point'}, 'surface_temperature': 83}
# {'confidence': 98, 'location': {'coordinates': [-37.4261, 147.0323], 'type': 'Point'}, 'surface_temperature': 83}
# {'confidence': 99, 'location': {'coordinates': [-37.609, 149.32], 'type': 'Point'}, 'surface_temperature': 84}
# {'confidence': 100, 'location': {'coordinates': [-37.399, 148.081], 'type': 'Point'}, 'surface_temperature': 84}
# {'confidence': 99, 'location': {'coordinates': [-38.0881, 143.9391], 'type': 'Point'}, 'surface_temperature': 84}
# {'confidence': 99, 'location': {'coordinates': [-36.4286, 141.1567], 'type': 'Point'}, 'surface_temperature': 84}
# {'confidence': 98, 'location': {'coordinates': [-36.8742, 142.7177], 'type': 'Point'}, 'surface_temperature': 84}
# {'confidence': 99, 'location': {'coordinates': [-36.5438, 144.7548], 'type': 'Point'}, 'surface_temperature': 84}
# {'confidence': 98, 'location': {'coordinates': [-36.1345, 146.351], 'type': 'Point'}, 'surface_temperature': 84}
# {'confidence': 98, 'location': {'coordinates': [-36.5262, 144.5737], 'type': 'Point'}, 'surface_temperature': 84}
# {'confidence': 99, 'location': {'coordinates': [-36.7943, 143.9571], 'type': 'Point'}, 'surface_temperature': 84}
# {'confidence': 99, 'location': {'coordinates': [-37.293, 141.245], 'type': 'Point'}, 'surface_temperature': 85}
# {'confidence': 94, 'location': {'coordinates': [-36.2693, 143.1768], 'type': 'Point'}, 'surface_temperature': 85}
# {'confidence': 99, 'location': {'coordinates': [-37.5867, 143.6256], 'type': 'Point'}, 'surface_temperature': 85}
# {'confidence': 99, 'location': {'coordinates': [-36.1586, 145.6666], 'type': 'Point'}, 'surface_temperature': 85}
# {'confidence': 99, 'location': {'coordinates': [-35.8276, 143.7549], 'type': 'Point'}, 'surface_temperature': 85}
# {'confidence': 99, 'location': {'coordinates': [-36.0691, 145.7797], 'type': 'Point'}, 'surface_temperature': 85}
# {'confidence': 99, 'location': {'coordinates': [-37.8885, 143.9157], 'type': 'Point'}, 'surface_temperature': 85}
# {'confidence': 99, 'location': {'coordinates': [-36.7287, 142.6017], 'type': 'Point'}, 'surface_temperature': 85}
# {'confidence': 99, 'location': {'coordinates': [-37.777, 148.4128], 'type': 'Point'}, 'surface_temperature': 85}
# {'confidence': 99, 'location': {'coordinates': [-37.6, 149.325], 'type': 'Point'}, 'surface_temperature': 86}
# {'confidence': 99, 'location': {'coordinates': [-36.2882, 141.1821], 'type': 'Point'}, 'surface_temperature': 86}
# {'confidence': 99, 'location': {'coordinates': [-36.7153, 143.8226], 'type': 'Point'}, 'surface_temperature': 86}
# {'confidence': 99, 'location': {'coordinates': [-37.5115, 143.14], 'type': 'Point'}, 'surface_temperature': 86}
# {'confidence': 100, 'location': {'coordinates': [-35.8768, 145.4627], 'type': 'Point'}, 'surface_temperature': 86}
# {'confidence': 94, 'location': {'coordinates': [-36.6349, 142.2125], 'type': 'Point'}, 'surface_temperature': 86}
# {'confidence': 99, 'location': {'coordinates': [-37.7236, 143.3995], 'type': 'Point'}, 'surface_temperature': 86}
# {'confidence': 99, 'location': {'coordinates': [-34.351, 141.6567], 'type': 'Point'}, 'surface_temperature': 86}
# {'confidence': 100, 'location': {'coordinates': [-37.606, 149.312], 'type': 'Point'}, 'surface_temperature': 87}
# {'confidence': 100, 'location': {'coordinates': [-37.294, 141.232], 'type': 'Point'}, 'surface_temperature': 87}
# {'confidence': 94, 'location': {'coordinates': [-37.4796, 141.9403], 'type': 'Point'}, 'surface_temperature': 87}
# {'confidence': 100, 'location': {'coordinates': [-36.345, 143.4256], 'type': 'Point'}, 'surface_temperature': 87}
# {'confidence': 100, 'location': {'coordinates': [-36.664, 142.8802], 'type': 'Point'}, 'surface_temperature': 87}
# {'confidence': 100, 'location': {'coordinates': [-37.8412, 147.2536], 'type': 'Point'}, 'surface_temperature': 87}
# {'confidence': 100, 'location': {'coordinates': [-37.9594, 143.5638], 'type': 'Point'}, 'surface_temperature': 87}
# {'confidence': 100, 'location': {'coordinates': [-36.7957, 143.9652], 'type': 'Point'}, 'surface_temperature': 87}
# {'confidence': 100, 'location': {'coordinates': [-36.0837, 144.2448], 'type': 'Point'}, 'surface_temperature': 87}
# {'confidence': 100, 'location': {'coordinates': [-37.406, 148.123], 'type': 'Point'}, 'surface_temperature': 88}
# {'confidence': 100, 'location': {'coordinates': [-36.3756, 143.7243], 'type': 'Point'}, 'surface_temperature': 88}
# {'confidence': 100, 'location': {'coordinates': [-36.7309, 142.3633], 'type': 'Point'}, 'surface_temperature': 88}
# {'confidence': 100, 'location': {'coordinates': [-37.9071, 143.538], 'type': 'Point'}, 'surface_temperature': 88}
# {'confidence': 100, 'location': {'coordinates': [-36.3999, 144.737], 'type': 'Point'}, 'surface_temperature': 88}
# {'confidence': 100, 'location': {'coordinates': [-37.3847, 142.8935], 'type': 'Point'}, 'surface_temperature': 88}
# {'confidence': 100, 'location': {'coordinates': [-37.8429, 143.8366], 'type': 'Point'}, 'surface_temperature': 88}
# {'confidence': 87, 'location': {'coordinates': [-37.6387, 142.9032], 'type': 'Point'}, 'surface_temperature': 88}
# {'confidence': 100, 'location': {'coordinates': [-36.3799, 143.7149], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 100, 'location': {'coordinates': [-38.5123, 146.4007], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 100, 'location': {'coordinates': [-36.7742, 145.1991], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 100, 'location': {'coordinates': [-37.7002, 142.9562], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 100, 'location': {'coordinates': [-37.0761, 141.0574], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 100, 'location': {'coordinates': [-37.4591, 144.9492], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 100, 'location': {'coordinates': [-37.2168, 147.4748], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 94, 'location': {'coordinates': [-38.0052, 142.6179], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 100, 'location': {'coordinates': [-37.383, 145.9089], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 100, 'location': {'coordinates': [-38.0693, 142.9722], 'type': 'Point'}, 'surface_temperature': 89}
# {'confidence': 100, 'location': {'coordinates': [-37.462, 148.089], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-37.9047, 141.0945], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-38.0361, 146.0567], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-36.1532, 143.5527], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-36.0682, 146.0602], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 87, 'location': {'coordinates': [-36.3332, 145.8594], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-36.6615, 144.6014], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-37.0899, 141.0238], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-37.1999, 143.8231], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-36.3972, 141.6041], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-37.2988, 143.5487], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-37.5012, 142.5853], 'type': 'Point'}, 'surface_temperature': 90}
# {'confidence': 100, 'location': {'coordinates': [-36.3459, 141.5586], 'type': 'Point'}, 'surface_temperature': 91}
# {'confidence': 100, 'location': {'coordinates': [-38.0795, 143.2449], 'type': 'Point'}, 'surface_temperature': 91}
# {'confidence': 100, 'location': {'coordinates': [-37.3949, 147.0175], 'type': 'Point'}, 'surface_temperature': 91}
# {'confidence': 100, 'location': {'coordinates': [-36.4125, 143.1189], 'type': 'Point'}, 'surface_temperature': 92}
# {'confidence': 100, 'location': {'coordinates': [-35.1857, 141.0604], 'type': 'Point'}, 'surface_temperature': 92}
# {'confidence': 100, 'location': {'coordinates': [-36.4409, 141.6948], 'type': 'Point'}, 'surface_temperature': 92}
# {'confidence': 100, 'location': {'coordinates': [-35.8182, 143.8739], 'type': 'Point'}, 'surface_temperature': 92}
# {'confidence': 100, 'location': {'coordinates': [-37.4343, 147.6327], 'type': 'Point'}, 'surface_temperature': 92}
# {'confidence': 87, 'location': {'coordinates': [-36.0973, 143.4279], 'type': 'Point'}, 'surface_temperature': 92}
# {'confidence': 100, 'location': {'coordinates': [-37.477, 143.352], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-38.4349, 146.3122], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-36.0077, 141.7747], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-36.8791, 142.7261], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-37.5043, 146.3299], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 94, 'location': {'coordinates': [-38.0792, 143.7361], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-36.8283, 143.4605], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-36.1771, 145.7451], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-36.7089, 143.3518], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-35.6469, 142.376], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-37.9174, 145.8678], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-37.297, 143.5753], 'type': 'Point'}, 'surface_temperature': 93}
# {'confidence': 100, 'location': {'coordinates': [-36.3433, 143.4369], 'type': 'Point'}, 'surface_temperature': 94}
# {'confidence': 100, 'location': {'coordinates': [-36.0576, 141.6122], 'type': 'Point'}, 'surface_temperature': 94}
# {'confidence': 100, 'location': {'coordinates': [-38.1917, 147.0745], 'type': 'Point'}, 'surface_temperature': 94}
# {'confidence': 100, 'location': {'coordinates': [-36.5854, 143.0462], 'type': 'Point'}, 'surface_temperature': 94}
# {'confidence': 100, 'location': {'coordinates': [-37.5701, 142.6497], 'type': 'Point'}, 'surface_temperature': 94}
# {'confidence': 100, 'location': {'coordinates': [-35.2378, 142.9864], 'type': 'Point'}, 'surface_temperature': 94}
# {'confidence': 100, 'location': {'coordinates': [-36.1506, 143.5671], 'type': 'Point'}, 'surface_temperature': 95}
# {'confidence': 100, 'location': {'coordinates': [-36.4035, 140.9935], 'type': 'Point'}, 'surface_temperature': 95}
# {'confidence': 100, 'location': {'coordinates': [-37.5027, 146.347], 'type': 'Point'}, 'surface_temperature': 95}
# {'confidence': 100, 'location': {'coordinates': [-38.027, 142.3844], 'type': 'Point'}, 'surface_temperature': 95}
# {'confidence': 100, 'location': {'coordinates': [-35.6374, 142.3787], 'type': 'Point'}, 'surface_temperature': 95}
# {'confidence': 100, 'location': {'coordinates': [-35.805, 142.1326], 'type': 'Point'}, 'surface_temperature': 95}
# {'confidence': 100, 'location': {'coordinates': [-36.9034, 141.0013], 'type': 'Point'}, 'surface_temperature': 95}
# {'confidence': 100, 'location': {'coordinates': [-37.3735, 145.8384], 'type': 'Point'}, 'surface_temperature': 95}
# {'confidence': 100, 'location': {'coordinates': [-36.5454, 144.7402], 'type': 'Point'}, 'surface_temperature': 96}
# {'confidence': 100, 'location': {'coordinates': [-37.4352, 143.1444], 'type': 'Point'}, 'surface_temperature': 96}
# {'confidence': 100, 'location': {'coordinates': [-36.91, 141.2705], 'type': 'Point'}, 'surface_temperature': 96}
# {'confidence': 100, 'location': {'coordinates': [-37.9246, 146.2464], 'type': 'Point'}, 'surface_temperature': 96}
# {'confidence': 94, 'location': {'coordinates': [-35.811, 142.1403], 'type': 'Point'}, 'surface_temperature': 96}
# {'confidence': 87, 'location': {'coordinates': [-37.3735, 145.886], 'type': 'Point'}, 'surface_temperature': 96}
# {'confidence': 100, 'location': {'coordinates': [-36.4142, 143.1077], 'type': 'Point'}, 'surface_temperature': 97}
# {'confidence': 100, 'location': {'coordinates': [-36.4518, 144.7752], 'type': 'Point'}, 'surface_temperature': 97}
# {'confidence': 100, 'location': {'coordinates': [-36.9918, 141.8667], 'type': 'Point'}, 'surface_temperature': 97}
# {'confidence': 87, 'location': {'coordinates': [-37.7974, 145.9535], 'type': 'Point'}, 'surface_temperature': 97}
# {'confidence': 100, 'location': {'coordinates': [-36.0816, 145.859], 'type': 'Point'}, 'surface_temperature': 98}
# {'confidence': 100, 'location': {'coordinates': [-36.7708, 145.1908], 'type': 'Point'}, 'surface_temperature': 98}
# {'confidence': 100, 'location': {'coordinates': [-37.3902, 148.2955], 'type': 'Point'}, 'surface_temperature': 98}
# {'confidence': 100, 'location': {'coordinates': [-37.5728, 142.6348], 'type': 'Point'}, 'surface_temperature': 98}
# {'confidence': 100, 'location': {'coordinates': [-37.5949, 142.6857], 'type': 'Point'}, 'surface_temperature': 98}
# {'confidence': 100, 'location': {'coordinates': [-37.8249, 143.6174], 'type': 'Point'}, 'surface_temperature': 98}
# {'confidence': 100, 'location': {'coordinates': [-36.1819, 145.9269], 'type': 'Point'}, 'surface_temperature': 98}
# {'confidence': 100, 'location': {'coordinates': [-37.3025, 143.5714], 'type': 'Point'}, 'surface_temperature': 98}
# {'confidence': 85, 'location': {'coordinates': [-37.4128, 147.0242], 'type': 'Point'}, 'surface_temperature': 98}
# {'confidence': 100, 'location': {'coordinates': [-36.5839, 143.0588], 'type': 'Point'}, 'surface_temperature': 99}
# {'confidence': 75, 'location': {'coordinates': [-36.7499, 141.3006], 'type': 'Point'}, 'surface_temperature': 99}
# {'confidence': 100, 'location': {'coordinates': [-38.0254, 142.3959], 'type': 'Point'}, 'surface_temperature': 99}
# {'confidence': 100, 'location': {'coordinates': [-37.782, 148.3844], 'type': 'Point'}, 'surface_temperature': 99}
# {'confidence': 100, 'location': {'coordinates': [-37.8881, 145.8229], 'type': 'Point'}, 'surface_temperature': 99}
# {'confidence': 100, 'location': {'coordinates': [-37.4229, 147.027], 'type': 'Point'}, 'surface_temperature': 99}
# {'confidence': 100, 'location': {'coordinates': [-36.1988, 145.0941], 'type': 'Point'}, 'surface_temperature': 100}
# {'confidence': 100, 'location': {'coordinates': [-36.9018, 141.0146], 'type': 'Point'}, 'surface_temperature': 100}

# %% [markdown]
# >- Find date, surface temperature (°C), air temperature (°C), relative humidity and
# max wind speed on 15th and 16th of December 2017.

# %%
#getting the data using the IDs and returns all parameters specified in `p_dict` parameter
def hs_obj(_id, params):
    p_dict = {p:1 for p in params}
    return to_dict(hotspot_coll.find({'_id':_id}, p_dict))

# %%
# returns the hotspot data corresponding to the ids present in climate data collection.
def get_hs_data(cursor_dict):
    obj_l = []
    obj = {}
    for c in cursor_dict:
        obj = dict(c)
        if 'hotspot_data' in c.keys():
            del obj['hotspot_data']
            for h in c['hotspot_data']:
                obj['surface_temperature'] = hs_obj(h['_id'],['surface_temperature']).get('surface_temperature')
                obj_l.append(obj)
        else:
            obj_l.append(obj)
    return obj_l

# %%
#searching for data of two dates using or operator
cursor_dict = to_dict(climate_coll.find({'$or':[{'date':format_date('15/12/2017')},{'date':format_date('16/12/2017')}]},{'_id':0,'precipitation':0,'station':0,'windspeed_knots':0})) 
date_specific_data = get_hs_data(cursor_dict)

# %%
for m in date_specific_data:
    print(m)
# Out:
# {'surface_temperature': 40, 'date': datetime.datetime(2017, 12, 15, 0, 0), 'max_wind_speed': 14.0, 'air_temperature': 18, 'relative_humidity': 52.0}
# {'surface_temperature': 40, 'date': datetime.datetime(2017, 12, 15, 0, 0), 'max_wind_speed': 14.0, 'air_temperature': 18, 'relative_humidity': 52.0}
# {'surface_temperature': 40, 'date': datetime.datetime(2017, 12, 15, 0, 0), 'max_wind_speed': 14.0, 'air_temperature': 18, 'relative_humidity': 52.0}
# {'surface_temperature': 40, 'date': datetime.datetime(2017, 12, 15, 0, 0), 'max_wind_speed': 14.0, 'air_temperature': 18, 'relative_humidity': 52.0}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}
# {'surface_temperature': 57, 'date': datetime.datetime(2017, 12, 16, 0, 0), 'max_wind_speed': 13.0, 'air_temperature': 18, 'relative_humidity': 53.7}

# %% [markdown]
# >- Find datetime, air temperature (°C), surface temperature (°C) and confidence
# when the confidence is between 80 and 100.

# %%
conf_range = hotspot_coll.aggregate([
    {
        '$match':{'confidence':{'$gte':80, '$lte':100}}     #confidence between 80 and 100 (inclusive)
    },
    {
        '$lookup':{
            'from':'climate_hotspot',           #Joining on dates the two collection and naming it as climate data
            'localField': 'date',
            'foreignField': 'date',
            'as': 'climate_data'
        }
    },
    {
        '$unwind': '$climate_data'                    #unwinding climate data
    },
    {
        '$project':{                                  #projecting selected values
            '_id':0,
            'datetime':1,
            'confidence':1,
            'surface_temperature':1,
            'air_temperature':1,
            'climate_data.air_temperature': 1
        }
    }
    
])

# %%
for doc in conf_range :
    print(doc)
# Out:
# {'confidence': 80, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 12, 25, 4, 29, 8)}
# {'confidence': 80, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 37, 'datetime': datetime.datetime(2017, 11, 11, 13, 30, 8)}
# {'confidence': 80, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 46, 'datetime': datetime.datetime(2017, 10, 20, 4, 41, 19)}
# {'confidence': 80, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 46, 'datetime': datetime.datetime(2017, 10, 4, 4, 41, 2)}
# {'confidence': 80, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 46, 'datetime': datetime.datetime(2017, 10, 4, 4, 41)}
# {'confidence': 80, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 50, 'datetime': datetime.datetime(2017, 9, 23, 4, 59, 11)}
# {'confidence': 80, 'climate_data': {'air_temperature': 11}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 9, 10, 4, 0)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 8, 13, 5, 5, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 22, 4, 43, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 8, 4, 20, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 4, 4, 51, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 4, 4, 51, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 4, 4, 48, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 4, 4, 46)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 4, 4, 45)}
# {'confidence': 80, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 1, 4, 14, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 20}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 20, 4, 32, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 39, 'datetime': datetime.datetime(2017, 4, 19, 13, 23, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 66, 'datetime': datetime.datetime(2017, 4, 19, 3, 51, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 18, 4, 51, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 18, 4, 50, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 18, 4, 46, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 17, 1, 20, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 16, 4, 57, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 15, 4, 16, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 13, 4, 36, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 33)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 32, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 13, 4, 29, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 27, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 59, 'datetime': datetime.datetime(2017, 4, 8, 4, 12)}
# {'confidence': 80, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 8, 4, 8, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 8, 4, 8, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 8, 4, 8, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 39, 'datetime': datetime.datetime(2017, 4, 7, 12, 56, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 7, 5, 9, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 7, 5, 3, 10)}
# {'confidence': 80, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 6, 4, 20, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 39, 'datetime': datetime.datetime(2017, 4, 5, 13, 2, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 4, 4, 33, 30)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 40)}
# {'confidence': 80, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 4, 0, 12, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 4, 3, 3, 51)}
# {'confidence': 80, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 3, 31, 4, 58)}
# {'confidence': 80, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 3, 28, 4, 30, 20)}
# {'confidence': 80, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 23}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 3, 26, 4, 40, 50)}
# {'confidence': 80, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 68, 'datetime': datetime.datetime(2017, 3, 12, 4, 28)}
# {'confidence': 81, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 12, 9, 0, 14, 34)}
# {'confidence': 81, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 42, 'datetime': datetime.datetime(2017, 11, 30, 12, 22, 15)}
# {'confidence': 81, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57)}
# {'confidence': 81, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53)}
# {'confidence': 81, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53)}
# {'confidence': 81, 'climate_data': {'air_temperature': 24}, 'surface_temperature': 53, 'datetime': datetime.datetime(2017, 11, 13, 3, 52, 14)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 10, 28, 3, 52, 17)}
# {'confidence': 81, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 48, 'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15)}
# {'confidence': 81, 'climate_data': {'air_temperature': 11}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 9, 10, 3, 50, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 5}, 'surface_temperature': 48, 'datetime': datetime.datetime(2017, 6, 30, 0, 27, 19)}
# {'confidence': 81, 'climate_data': {'air_temperature': 5}, 'surface_temperature': 48, 'datetime': datetime.datetime(2017, 6, 30, 0, 27, 19)}
# {'confidence': 81, 'climate_data': {'air_temperature': 8}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 6, 7, 4, 32, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 23, 0, 54, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 13, 4, 39, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 10, 4, 11, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 39, 'datetime': datetime.datetime(2017, 5, 9, 12, 56, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 9, 5, 2, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 5, 3, 57)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 4, 4, 46, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 4, 4, 45, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 4, 4, 44, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 4, 4, 44, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 5, 2, 23, 44)}
# {'confidence': 81, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 23, 5, 2, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 39, 'datetime': datetime.datetime(2017, 4, 19, 13, 15, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 18, 4, 51, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 45, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 45)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 60, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 17, 4, 8, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 17, 4, 2, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 15, 4, 16)}
# {'confidence': 81, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 15, 4, 15)}
# {'confidence': 81, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 34, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 33, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 29, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 29, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 27, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 27, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 11, 4, 39, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 7, 5, 3, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 6, 4, 27, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 71, 'datetime': datetime.datetime(2017, 4, 6, 4, 22, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 60, 'datetime': datetime.datetime(2017, 4, 6, 4, 20, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 61, 'datetime': datetime.datetime(2017, 4, 6, 4, 20, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 6, 4, 20, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 39, 'datetime': datetime.datetime(2017, 4, 5, 13, 9)}
# {'confidence': 81, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 39, 'datetime': datetime.datetime(2017, 4, 5, 13, 3)}
# {'confidence': 81, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 5, 3, 40, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 4, 4, 39, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 4, 4, 33, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 3, 3, 51)}
# {'confidence': 81, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 4, 3, 1, 7, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 3, 31, 0, 36, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 3, 28, 4, 30, 10)}
# {'confidence': 81, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 3, 28, 4, 28, 30)}
# {'confidence': 81, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 23}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 3, 26, 4, 43, 20)}
# {'confidence': 81, 'climate_data': {'air_temperature': 23}, 'surface_temperature': 54, 'datetime': datetime.datetime(2017, 3, 26, 4, 39, 50)}
# {'confidence': 81, 'climate_data': {'air_temperature': 25}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 3, 14, 4, 14, 40)}
# {'confidence': 81, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 3, 10, 4, 43, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 28}, 'surface_temperature': 63, 'datetime': datetime.datetime(2017, 12, 27, 0, 2, 15)}
# {'confidence': 82, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 12, 16, 0, 21, 11)}
# {'confidence': 82, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 64, 'datetime': datetime.datetime(2017, 12, 16, 0, 20, 53)}
# {'confidence': 82, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 50, 'datetime': datetime.datetime(2017, 10, 20, 4, 41, 19)}
# {'confidence': 82, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 10, 18, 0, 39, 2)}
# {'confidence': 82, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 10, 17, 4, 10, 32)}
# {'confidence': 82, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 49, 'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 49, 'datetime': datetime.datetime(2017, 9, 29, 4, 22, 31)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 38, 'datetime': datetime.datetime(2017, 9, 24, 13, 30, 9)}
# {'confidence': 82, 'climate_data': {'air_temperature': 11}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 6, 1, 5, 9, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40)}
# {'confidence': 82, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40)}
# {'confidence': 82, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 5, 3, 51, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 5, 3, 50, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 5, 5, 3, 50, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 4, 4, 46, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 4, 4, 45, 40)}
# {'confidence': 82, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 3, 4, 8, 10)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 1, 4, 14, 30)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 5, 1, 4, 14, 30)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 62, 'datetime': datetime.datetime(2017, 5, 1, 4, 14, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 25, 5, 2, 30)}
# {'confidence': 82, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 19, 3, 51, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 18, 4, 55)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 18, 4, 51, 30)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 18, 4, 51, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 18, 4, 45, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 18, 4, 45, 40)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 17, 4, 3, 10)}
# {'confidence': 82, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 15, 4, 16)}
# {'confidence': 82, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 15, 4, 15, 40)}
# {'confidence': 82, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 15, 4, 15, 10)}
# {'confidence': 82, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 14, 5, 15, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 33)}
# {'confidence': 82, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 82, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 82, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 13, 0, 7, 40)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 12, 3, 44, 40)}
# {'confidence': 82, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 6, 4, 20, 40)}
# {'confidence': 82, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 40, 'datetime': datetime.datetime(2017, 4, 5, 13, 7)}
# {'confidence': 82, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 62, 'datetime': datetime.datetime(2017, 4, 5, 3, 39, 30)}
# {'confidence': 82, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 62, 'datetime': datetime.datetime(2017, 4, 4, 4, 41, 10)}
# {'confidence': 82, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 62, 'datetime': datetime.datetime(2017, 4, 4, 4, 33, 10)}
# {'confidence': 82, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 62, 'datetime': datetime.datetime(2017, 4, 4, 4, 33, 10)}
# {'confidence': 82, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 50)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 3, 3, 56, 20)}
# {'confidence': 82, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 3, 3, 50, 40)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 3, 31, 5, 7, 10)}
# {'confidence': 82, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 3, 31, 4, 58, 30)}
# {'confidence': 82, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 3, 28, 4, 27)}
# {'confidence': 82, 'climate_data': {'air_temperature': 23}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10)}
# {'confidence': 82, 'climate_data': {'air_temperature': 23}, 'surface_temperature': 65, 'datetime': datetime.datetime(2017, 3, 25, 3, 59, 50)}
# {'confidence': 83, 'climate_data': {'air_temperature': 28}, 'surface_temperature': 60, 'datetime': datetime.datetime(2017, 12, 13, 4, 4, 19)}
# {'confidence': 83, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 11, 30, 0, 20, 53)}
# {'confidence': 83, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 11, 5, 4, 41, 34)}
# {'confidence': 83, 'climate_data': {'air_temperature': 11}, 'surface_temperature': 50, 'datetime': datetime.datetime(2017, 10, 2, 4, 53, 10)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 9, 27, 4, 35, 36)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 8, 13, 5, 2, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 7, 6, 4, 8)}
# {'confidence': 83, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 6, 2, 4, 14, 10)}
# {'confidence': 83, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 6, 2, 4, 14, 10)}
# {'confidence': 83, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 5, 15, 4, 33)}
# {'confidence': 83, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 63, 'datetime': datetime.datetime(2017, 5, 15, 4, 29, 50)}
# {'confidence': 83, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20)}
# {'confidence': 83, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20)}
# {'confidence': 83, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 63, 'datetime': datetime.datetime(2017, 5, 13, 4, 39, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 5, 12, 3, 57, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 5, 10, 4, 11, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 5, 8, 4, 20, 20)}
# {'confidence': 83, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 5, 6, 0, 16, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 77, 'datetime': datetime.datetime(2017, 5, 1, 4, 14, 20)}
# {'confidence': 83, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 40, 'datetime': datetime.datetime(2017, 4, 19, 13, 18, 20)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 18, 4, 48, 20)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 18, 0, 24, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 18, 0, 24, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 17, 4, 3, 50)}
# {'confidence': 83, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 17, 1, 19, 10)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 16, 5, 7, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 16, 4, 56, 50)}
# {'confidence': 83, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 12, 3, 47, 20)}
# {'confidence': 83, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 6, 4, 27)}
# {'confidence': 83, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 64, 'datetime': datetime.datetime(2017, 4, 6, 4, 24, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 6, 4, 22, 20)}
# {'confidence': 83, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 63, 'datetime': datetime.datetime(2017, 4, 6, 4, 20, 50)}
# {'confidence': 83, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 78, 'datetime': datetime.datetime(2017, 4, 6, 4, 20, 40)}
# {'confidence': 83, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 4, 5, 3, 39, 20)}
# {'confidence': 83, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 64, 'datetime': datetime.datetime(2017, 4, 5, 3, 39, 10)}
# {'confidence': 83, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 4, 4, 34, 50)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 40, 'datetime': datetime.datetime(2017, 4, 3, 13, 15, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 63, 'datetime': datetime.datetime(2017, 4, 3, 3, 51, 30)}
# {'confidence': 83, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 56, 'datetime': datetime.datetime(2017, 3, 28, 4, 30, 50)}
# {'confidence': 83, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50)}
# {'confidence': 83, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 12, 16, 4, 34, 58)}
# {'confidence': 84, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 12, 9, 0, 14, 33)}
# {'confidence': 84, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 38, 'datetime': datetime.datetime(2017, 11, 30, 12, 22, 15)}
# {'confidence': 84, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 59, 'datetime': datetime.datetime(2017, 11, 30, 4, 35)}
# {'confidence': 84, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 61, 'datetime': datetime.datetime(2017, 11, 30, 4, 34, 57)}
# {'confidence': 84, 'climate_data': {'air_temperature': 24}, 'surface_temperature': 60, 'datetime': datetime.datetime(2017, 11, 23, 4, 28, 59)}
# {'confidence': 84, 'climate_data': {'air_temperature': 23}, 'surface_temperature': 59, 'datetime': datetime.datetime(2017, 11, 22, 3, 46)}
# {'confidence': 84, 'climate_data': {'air_temperature': 26}, 'surface_temperature': 59, 'datetime': datetime.datetime(2017, 10, 18, 0, 39, 2)}
# {'confidence': 84, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 10, 3, 3, 58, 15)}
# {'confidence': 84, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 52, 'datetime': datetime.datetime(2017, 10, 1, 4, 10, 28)}
# {'confidence': 84, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 50, 'datetime': datetime.datetime(2017, 9, 24, 13, 30, 7)}
# {'confidence': 84, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 52, 'datetime': datetime.datetime(2017, 9, 24, 4, 4, 4)}
# {'confidence': 84, 'climate_data': {'air_temperature': 11}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 9, 10, 3, 53)}
# {'confidence': 84, 'climate_data': {'air_temperature': 6}, 'surface_temperature': 52, 'datetime': datetime.datetime(2017, 7, 2, 4, 29, 18)}
# {'confidence': 84, 'climate_data': {'air_temperature': 6}, 'surface_temperature': 52, 'datetime': datetime.datetime(2017, 7, 2, 4, 29, 18)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 52, 'datetime': datetime.datetime(2017, 6, 9, 4, 23, 20)}
# {'confidence': 84, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 59, 'datetime': datetime.datetime(2017, 5, 23, 0, 58)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 15, 4, 32, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 15, 4, 29, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 5, 15, 4, 26, 20)}
# {'confidence': 84, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40)}
# {'confidence': 84, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 13, 4, 38, 40)}
# {'confidence': 84, 'climate_data': {'air_temperature': 9}, 'surface_temperature': 78, 'datetime': datetime.datetime(2017, 5, 11, 4, 50, 40)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 10, 4, 16, 10)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 68, 'datetime': datetime.datetime(2017, 5, 10, 4, 11, 10)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 10, 4, 8, 10)}
# {'confidence': 84, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 5, 5, 3, 53, 10)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 4, 4, 46, 20)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 4, 4, 44, 40)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 5, 3, 4, 5, 20)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 3, 4, 2, 20)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 3, 4, 2, 20)}
# {'confidence': 84, 'climate_data': {'air_temperature': 10}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 5, 3, 4, 2, 20)}
# {'confidence': 84, 'climate_data': {'air_temperature': 20}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 20, 4, 44, 20)}
# {'confidence': 84, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 19, 3, 51, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 19, 3, 50, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 19, 3, 50, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 18, 4, 45, 10)}
# {'confidence': 84, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 18, 4, 45)}
# {'confidence': 84, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 66, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 57, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 17, 4, 2, 20)}
# {'confidence': 84, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 15, 4, 15, 10)}
# {'confidence': 84, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 79, 'datetime': datetime.datetime(2017, 4, 14, 5, 9, 10)}
# {'confidence': 84, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 78, 'datetime': datetime.datetime(2017, 4, 14, 5, 9, 10)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 33, 40)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 40)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 80, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 84, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 12, 5, 28)}
# {'confidence': 84, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 12, 3, 47, 50)}
# {'confidence': 84, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 12, 3, 47, 30)}
# ...
# {'confidence': 100, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 95, 'datetime': datetime.datetime(2017, 4, 19, 3, 50, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 22}, 'surface_temperature': 93, 'datetime': datetime.datetime(2017, 4, 19, 3, 50, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 124, 'datetime': datetime.datetime(2017, 4, 18, 4, 52)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 113, 'datetime': datetime.datetime(2017, 4, 18, 4, 48, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 94, 'datetime': datetime.datetime(2017, 4, 18, 4, 47, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 87, 'datetime': datetime.datetime(2017, 4, 18, 4, 45, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 114, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 120, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 89, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 98, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 96, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 101, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 117, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 86, 'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 93, 'datetime': datetime.datetime(2017, 4, 15, 4, 15)}
# {'confidence': 100, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 116, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 111, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 90, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 110, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 103, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 12}, 'surface_temperature': 100, 'datetime': datetime.datetime(2017, 4, 15, 4, 14, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 13}, 'surface_temperature': 87, 'datetime': datetime.datetime(2017, 4, 14, 3, 33)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 97, 'datetime': datetime.datetime(2017, 4, 13, 4, 38)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 89, 'datetime': datetime.datetime(2017, 4, 13, 4, 34, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 88, 'datetime': datetime.datetime(2017, 4, 13, 4, 33, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 96, 'datetime': datetime.datetime(2017, 4, 13, 4, 33, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 93, 'datetime': datetime.datetime(2017, 4, 13, 4, 29, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 95, 'datetime': datetime.datetime(2017, 4, 13, 4, 29, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 114, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 120, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 90, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 102, 'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 88, 'datetime': datetime.datetime(2017, 4, 13, 4, 27, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 113, 'datetime': datetime.datetime(2017, 4, 13, 4, 27, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 95, 'datetime': datetime.datetime(2017, 4, 13, 4, 27, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 92, 'datetime': datetime.datetime(2017, 4, 13, 4, 27, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 101, 'datetime': datetime.datetime(2017, 4, 13, 4, 27)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 107, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 115, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 89, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 104, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 97, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 87, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 93, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 112, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 110, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 108, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 90, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 99, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 91, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 92, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 93, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 92, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 111, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 93, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 92, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 111, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 96, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 90, 'datetime': datetime.datetime(2017, 4, 13, 4, 26, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 106, 'datetime': datetime.datetime(2017, 4, 12, 5, 28, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 98, 'datetime': datetime.datetime(2017, 4, 12, 5, 21, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 106, 'datetime': datetime.datetime(2017, 4, 12, 3, 47, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 98, 'datetime': datetime.datetime(2017, 4, 12, 3, 44, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 14}, 'surface_temperature': 111, 'datetime': datetime.datetime(2017, 4, 12, 3, 44, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 94, 'datetime': datetime.datetime(2017, 4, 8, 4, 12, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 49, 'datetime': datetime.datetime(2017, 4, 7, 12, 51)}
# {'confidence': 100, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 89, 'datetime': datetime.datetime(2017, 4, 7, 3, 31, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 106, 'datetime': datetime.datetime(2017, 4, 7, 3, 27, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 95, 'datetime': datetime.datetime(2017, 4, 6, 4, 27, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 88, 'datetime': datetime.datetime(2017, 4, 6, 4, 27, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 97, 'datetime': datetime.datetime(2017, 4, 6, 4, 27)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 99, 'datetime': datetime.datetime(2017, 4, 6, 4, 27)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 103, 'datetime': datetime.datetime(2017, 4, 6, 4, 22, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 115, 'datetime': datetime.datetime(2017, 4, 6, 4, 21)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 95, 'datetime': datetime.datetime(2017, 4, 6, 4, 20, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 100, 'datetime': datetime.datetime(2017, 4, 6, 4, 20, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 58, 'datetime': datetime.datetime(2017, 4, 5, 13, 9)}
# {'confidence': 100, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 47, 'datetime': datetime.datetime(2017, 4, 5, 13, 8, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 49, 'datetime': datetime.datetime(2017, 4, 5, 13, 4, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 5, 13, 3, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 55, 'datetime': datetime.datetime(2017, 4, 5, 13, 3)}
# {'confidence': 100, 'climate_data': {'air_temperature': 17}, 'surface_temperature': 92, 'datetime': datetime.datetime(2017, 4, 5, 3, 39, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 64, 'datetime': datetime.datetime(2017, 4, 4, 15, 30, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 120, 'datetime': datetime.datetime(2017, 4, 4, 4, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 107, 'datetime': datetime.datetime(2017, 4, 4, 4, 39, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 95, 'datetime': datetime.datetime(2017, 4, 4, 4, 35)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 113, 'datetime': datetime.datetime(2017, 4, 4, 4, 33, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 123, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 118, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 120, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 101, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 16}, 'surface_temperature': 98, 'datetime': datetime.datetime(2017, 4, 4, 4, 32, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 62, 'datetime': datetime.datetime(2017, 4, 3, 13, 15, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 93, 'datetime': datetime.datetime(2017, 4, 3, 3, 53, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 90, 'datetime': datetime.datetime(2017, 4, 3, 3, 52, 30)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 115, 'datetime': datetime.datetime(2017, 4, 3, 3, 52, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 98, 'datetime': datetime.datetime(2017, 4, 3, 3, 52, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 89, 'datetime': datetime.datetime(2017, 4, 3, 3, 52, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 15}, 'surface_temperature': 103, 'datetime': datetime.datetime(2017, 4, 3, 3, 51)}
# {'confidence': 100, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 107, 'datetime': datetime.datetime(2017, 3, 28, 4, 27, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 108, 'datetime': datetime.datetime(2017, 3, 28, 4, 27, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 18}, 'surface_temperature': 90, 'datetime': datetime.datetime(2017, 3, 28, 4, 26, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 23}, 'surface_temperature': 89, 'datetime': datetime.datetime(2017, 3, 26, 4, 39, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 23}, 'surface_temperature': 111, 'datetime': datetime.datetime(2017, 3, 25, 3, 57, 10)}
# {'confidence': 100, 'climate_data': {'air_temperature': 23}, 'surface_temperature': 99, 'datetime': datetime.datetime(2017, 3, 25, 3, 56, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 24}, 'surface_temperature': 91, 'datetime': datetime.datetime(2017, 3, 19, 4, 32, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 24}, 'surface_temperature': 113, 'datetime': datetime.datetime(2017, 3, 19, 4, 32, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 24}, 'surface_temperature': 106, 'datetime': datetime.datetime(2017, 3, 19, 4, 32, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 121, 'datetime': datetime.datetime(2017, 3, 18, 3, 50, 50)}
# {'confidence': 100, 'climate_data': {'air_temperature': 21}, 'surface_temperature': 99, 'datetime': datetime.datetime(2017, 3, 12, 4, 28, 20)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 105, 'datetime': datetime.datetime(2017, 3, 10, 4, 48, 40)}
# {'confidence': 100, 'climate_data': {'air_temperature': 19}, 'surface_temperature': 109, 'datetime': datetime.datetime(2017, 3, 10, 4, 46, 20)}

# %% [markdown]
# >- Find the top 10 records with the highest surface temperature (°C)

# %%
#sort data in descending order and project top 10 data
top_surf_tmp = hotspot_coll.find({},{'_id':0}).sort('surface_temperature',DESCENDING).limit(10)

# %%
for m in top_surf_tmp:
    print(m)
# Out:
# {'datetime': datetime.datetime(2017, 4, 18, 4, 52), 'confidence': 100, 'location': {'coordinates': [-38.1665, 143.062], 'type': 'Point'}, 'surface_temperature': 124, 'date': datetime.datetime(2017, 4, 18, 0, 0)}
# {'datetime': datetime.datetime(2017, 4, 4, 4, 32, 50), 'confidence': 100, 'location': {'coordinates': [-36.343, 142.1986], 'type': 'Point'}, 'surface_temperature': 123, 'date': datetime.datetime(2017, 4, 4, 0, 0)}
# {'datetime': datetime.datetime(2017, 5, 1, 4, 14, 20), 'confidence': 100, 'location': {'coordinates': [-36.9318, 143.0907], 'type': 'Point'}, 'surface_temperature': 122, 'date': datetime.datetime(2017, 5, 1, 0, 0)}
# {'datetime': datetime.datetime(2017, 3, 18, 3, 50, 50), 'confidence': 100, 'location': {'coordinates': [-37.017, 148.1297], 'type': 'Point'}, 'surface_temperature': 121, 'date': datetime.datetime(2017, 3, 18, 0, 0)}
# {'datetime': datetime.datetime(2017, 4, 4, 4, 32, 40), 'confidence': 100, 'location': {'coordinates': [-36.3521, 142.2008], 'type': 'Point'}, 'surface_temperature': 120, 'date': datetime.datetime(2017, 4, 4, 0, 0)}
# {'datetime': datetime.datetime(2017, 4, 4, 4, 40), 'confidence': 100, 'location': {'coordinates': [-36.1057, 141.7608], 'type': 'Point'}, 'surface_temperature': 120, 'date': datetime.datetime(2017, 4, 4, 0, 0)}
# {'datetime': datetime.datetime(2017, 4, 13, 4, 28, 10), 'confidence': 100, 'location': {'coordinates': [-37.0745, 141.0692], 'type': 'Point'}, 'surface_temperature': 120, 'date': datetime.datetime(2017, 4, 13, 0, 0)}
# {'datetime': datetime.datetime(2017, 4, 18, 4, 44, 50), 'confidence': 100, 'location': {'coordinates': [-37.8326, 143.4999], 'type': 'Point'}, 'surface_temperature': 120, 'date': datetime.datetime(2017, 4, 18, 0, 0)}
# {'datetime': datetime.datetime(2017, 5, 13, 4, 40, 20), 'confidence': 100, 'location': {'coordinates': [-34.9938, 141.876], 'type': 'Point'}, 'surface_temperature': 120, 'date': datetime.datetime(2017, 5, 13, 0, 0)}
# {'datetime': datetime.datetime(2017, 5, 4, 4, 44, 50), 'confidence': 100, 'location': {'coordinates': [-36.4057, 140.9806], 'type': 'Point'}, 'surface_temperature': 119, 'date': datetime.datetime(2017, 5, 4, 0, 0)}

# %% [markdown]
# >- Find the number of fire in each day.

# %%
#Find the number of fire in each day. 
num_fire = hotspot_coll.aggregate([{
    '$group': {                                       #grouping the data on date and sum 
        '_id':'$date',
        'number of fires':{'$sum':1}
    }
    
},
{ 
        '$project':{                                  #projecting the selected values
            '_id':0,
            'date': '$_id',
            'number of fires': 1
        }
    }
])

# %%
for m in num_fire:
    print(m)
# Out:
# {'number of fires': 2, 'date': datetime.datetime(2017, 3, 6, 0, 0)}
# {'number of fires': 8, 'date': datetime.datetime(2017, 3, 10, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 3, 12, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 3, 13, 0, 0)}
# {'number of fires': 7, 'date': datetime.datetime(2017, 3, 15, 0, 0)}
# {'number of fires': 6, 'date': datetime.datetime(2017, 3, 17, 0, 0)}
# {'number of fires': 21, 'date': datetime.datetime(2017, 3, 19, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 3, 24, 0, 0)}
# {'number of fires': 54, 'date': datetime.datetime(2017, 3, 28, 0, 0)}
# {'number of fires': 22, 'date': datetime.datetime(2017, 3, 31, 0, 0)}
# {'number of fires': 7, 'date': datetime.datetime(2017, 4, 1, 0, 0)}
# {'number of fires': 118, 'date': datetime.datetime(2017, 4, 6, 0, 0)}
# {'number of fires': 72, 'date': datetime.datetime(2017, 4, 3, 0, 0)}
# {'number of fires': 39, 'date': datetime.datetime(2017, 4, 7, 0, 0)}
# {'number of fires': 357, 'date': datetime.datetime(2017, 4, 13, 0, 0)}
# {'number of fires': 18, 'date': datetime.datetime(2017, 4, 14, 0, 0)}
# {'number of fires': 69, 'date': datetime.datetime(2017, 4, 15, 0, 0)}
# {'number of fires': 38, 'date': datetime.datetime(2017, 4, 17, 0, 0)}
# {'number of fires': 50, 'date': datetime.datetime(2017, 4, 19, 0, 0)}
# {'number of fires': 31, 'date': datetime.datetime(2017, 4, 20, 0, 0)}
# {'number of fires': 325, 'date': datetime.datetime(2017, 4, 18, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 4, 22, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 4, 25, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 4, 26, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 4, 29, 0, 0)}
# {'number of fires': 10, 'date': datetime.datetime(2017, 5, 2, 0, 0)}
# {'number of fires': 64, 'date': datetime.datetime(2017, 5, 3, 0, 0)}
# {'number of fires': 135, 'date': datetime.datetime(2017, 5, 4, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 5, 7, 0, 0)}
# {'number of fires': 7, 'date': datetime.datetime(2017, 10, 2, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 8, 5, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 10, 4, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 10, 7, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 10, 8, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 12, 15, 0, 0)}
# {'number of fires': 23, 'date': datetime.datetime(2017, 9, 23, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 10, 9, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 7, 31, 0, 0)}
# {'number of fires': 54, 'date': datetime.datetime(2017, 5, 13, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 10, 23, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 10, 21, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 12, 12, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 10, 28, 0, 0)}
# {'number of fires': 31, 'date': datetime.datetime(2017, 5, 5, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 10, 10, 0, 0)}
# {'number of fires': 24, 'date': datetime.datetime(2017, 4, 11, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 8, 1, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 3, 29, 0, 0)}
# {'number of fires': 8, 'date': datetime.datetime(2017, 4, 24, 0, 0)}
# {'number of fires': 14, 'date': datetime.datetime(2017, 6, 7, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 11, 8, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 10, 6, 0, 0)}
# {'number of fires': 10, 'date': datetime.datetime(2017, 11, 9, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 10, 26, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 9, 29, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 12, 8, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 12, 13, 0, 0)}
# {'number of fires': 24, 'date': datetime.datetime(2017, 5, 8, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 5, 16, 0, 0)}
# {'number of fires': 6, 'date': datetime.datetime(2017, 6, 30, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 12, 21, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 12, 27, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 4, 2, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 12, 25, 0, 0)}
# {'number of fires': 8, 'date': datetime.datetime(2017, 10, 1, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 12, 10, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 11, 14, 0, 0)}
# {'number of fires': 13, 'date': datetime.datetime(2017, 3, 25, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 11, 5, 0, 0)}
# {'number of fires': 7, 'date': datetime.datetime(2017, 9, 27, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 6, 22, 0, 0)}
# {'number of fires': 10, 'date': datetime.datetime(2017, 5, 12, 0, 0)}
# {'number of fires': 15, 'date': datetime.datetime(2017, 12, 16, 0, 0)}
# {'number of fires': 8, 'date': datetime.datetime(2017, 11, 29, 0, 0)}
# {'number of fires': 19, 'date': datetime.datetime(2017, 5, 11, 0, 0)}
# {'number of fires': 31, 'date': datetime.datetime(2017, 11, 30, 0, 0)}
# {'number of fires': 20, 'date': datetime.datetime(2017, 4, 8, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 7, 29, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 6, 14, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 3, 7, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 11, 28, 0, 0)}
# {'number of fires': 7, 'date': datetime.datetime(2017, 5, 18, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 10, 16, 0, 0)}
# {'number of fires': 89, 'date': datetime.datetime(2017, 4, 4, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 6, 13, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 6, 1, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 3, 18, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 12, 24, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 11, 21, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 3, 9, 0, 0)}
# {'number of fires': 6, 'date': datetime.datetime(2017, 10, 18, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 11, 22, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 10, 27, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 11, 12, 0, 0)}
# {'number of fires': 17, 'date': datetime.datetime(2017, 5, 6, 0, 0)}
# {'number of fires': 6, 'date': datetime.datetime(2017, 6, 20, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 12, 14, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 10, 20, 0, 0)}
# {'number of fires': 18, 'date': datetime.datetime(2017, 4, 16, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 11, 23, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 11, 13, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 10, 15, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 11, 11, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 9, 26, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 9, 22, 0, 0)}
# {'number of fires': 33, 'date': datetime.datetime(2017, 5, 22, 0, 0)}
# {'number of fires': 20, 'date': datetime.datetime(2017, 5, 1, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 10, 17, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 9, 20, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 9, 10, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 8, 14, 0, 0)}
# {'number of fires': 9, 'date': datetime.datetime(2017, 8, 13, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 8, 10, 0, 0)}
# {'number of fires': 49, 'date': datetime.datetime(2017, 4, 5, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 8, 2, 0, 0)}
# {'number of fires': 28, 'date': datetime.datetime(2017, 9, 24, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 7, 6, 0, 0)}
# {'number of fires': 102, 'date': datetime.datetime(2017, 5, 15, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 3, 8, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 7, 5, 0, 0)}
# {'number of fires': 10, 'date': datetime.datetime(2017, 3, 14, 0, 0)}
# {'number of fires': 5, 'date': datetime.datetime(2017, 5, 23, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 7, 4, 0, 0)}
# {'number of fires': 19, 'date': datetime.datetime(2017, 4, 23, 0, 0)}
# {'number of fires': 8, 'date': datetime.datetime(2017, 7, 2, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 7, 14, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 6, 18, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 7, 1, 0, 0)}
# {'number of fires': 18, 'date': datetime.datetime(2017, 10, 3, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 6, 16, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 6, 11, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 12, 9, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 6, 9, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 9, 21, 0, 0)}
# {'number of fires': 9, 'date': datetime.datetime(2017, 6, 4, 0, 0)}
# {'number of fires': 2, 'date': datetime.datetime(2017, 6, 3, 0, 0)}
# {'number of fires': 11, 'date': datetime.datetime(2017, 6, 2, 0, 0)}
# {'number of fires': 4, 'date': datetime.datetime(2017, 5, 26, 0, 0)}
# {'number of fires': 17, 'date': datetime.datetime(2017, 3, 26, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 5, 14, 0, 0)}
# {'number of fires': 3, 'date': datetime.datetime(2017, 5, 24, 0, 0)}
# {'number of fires': 1, 'date': datetime.datetime(2017, 5, 17, 0, 0)}
# {'number of fires': 114, 'date': datetime.datetime(2017, 5, 10, 0, 0)}
# {'number of fires': 69, 'date': datetime.datetime(2017, 4, 12, 0, 0)}
# {'number of fires': 13, 'date': datetime.datetime(2017, 5, 9, 0, 0)}

# %% [markdown]
# >- Find the average surface temperature(°C) for each day.

# %%
# Find the average surface temperature(°C) for each day.  
avg_st = hotspot_coll.aggregate([{
    '$group': {       #grouping on date and taking averages of all the surface data on pirticular dates
        '_id':'$date',
        'average surface temperature':{'$avg':'$surface_temperature'}          
    }
    
},
{
        '$project':{     #proecting required fields
            '_id':0,
            'date': '$_id',
            'average surface temperature': 1
        }
    }
])

# %%
for m in avg_st:
    print(m)
# Out:
# {'average surface temperature': 60.5, 'date': datetime.datetime(2017, 3, 6, 0, 0)}
# {'average surface temperature': 69.375, 'date': datetime.datetime(2017, 3, 10, 0, 0)}
# {'average surface temperature': 88.2, 'date': datetime.datetime(2017, 3, 12, 0, 0)}
# {'average surface temperature': 38.5, 'date': datetime.datetime(2017, 3, 13, 0, 0)}
# {'average surface temperature': 46.0, 'date': datetime.datetime(2017, 3, 15, 0, 0)}
# {'average surface temperature': 59.5, 'date': datetime.datetime(2017, 3, 17, 0, 0)}
# {'average surface temperature': 65.57142857142857, 'date': datetime.datetime(2017, 3, 19, 0, 0)}
# {'average surface temperature': 49.0, 'date': datetime.datetime(2017, 3, 24, 0, 0)}
# {'average surface temperature': 60.925925925925924, 'date': datetime.datetime(2017, 3, 28, 0, 0)}
# {'average surface temperature': 48.72727272727273, 'date': datetime.datetime(2017, 3, 31, 0, 0)}
# {'average surface temperature': 46.714285714285715, 'date': datetime.datetime(2017, 4, 1, 0, 0)}
# {'average surface temperature': 61.71186440677966, 'date': datetime.datetime(2017, 4, 6, 0, 0)}
# {'average surface temperature': 58.44444444444444, 'date': datetime.datetime(2017, 4, 3, 0, 0)}
# {'average surface temperature': 50.69230769230769, 'date': datetime.datetime(2017, 4, 7, 0, 0)}
# {'average surface temperature': 58.57983193277311, 'date': datetime.datetime(2017, 4, 13, 0, 0)}
# {'average surface temperature': 61.94444444444444, 'date': datetime.datetime(2017, 4, 14, 0, 0)}
# {'average surface temperature': 59.57971014492754, 'date': datetime.datetime(2017, 4, 15, 0, 0)}
# {'average surface temperature': 50.921052631578945, 'date': datetime.datetime(2017, 4, 17, 0, 0)}
# {'average surface temperature': 54.16, 'date': datetime.datetime(2017, 4, 19, 0, 0)}
# {'average surface temperature': 56.58064516129032, 'date': datetime.datetime(2017, 4, 20, 0, 0)}
# {'average surface temperature': 53.36615384615384, 'date': datetime.datetime(2017, 4, 18, 0, 0)}
# {'average surface temperature': 54.5, 'date': datetime.datetime(2017, 4, 22, 0, 0)}
# {'average surface temperature': 48.666666666666664, 'date': datetime.datetime(2017, 4, 25, 0, 0)}
# {'average surface temperature': 34.0, 'date': datetime.datetime(2017, 4, 26, 0, 0)}
# {'average surface temperature': 63.0, 'date': datetime.datetime(2017, 4, 29, 0, 0)}
# {'average surface temperature': 55.6, 'date': datetime.datetime(2017, 5, 2, 0, 0)}
# {'average surface temperature': 56.796875, 'date': datetime.datetime(2017, 5, 3, 0, 0)}
# {'average surface temperature': 56.80740740740741, 'date': datetime.datetime(2017, 5, 4, 0, 0)}
# {'average surface temperature': 50.333333333333336, 'date': datetime.datetime(2017, 5, 7, 0, 0)}
# {'average surface temperature': 43.57142857142857, 'date': datetime.datetime(2017, 10, 2, 0, 0)}
# {'average surface temperature': 40.0, 'date': datetime.datetime(2017, 8, 5, 0, 0)}
# {'average surface temperature': 49.0, 'date': datetime.datetime(2017, 10, 4, 0, 0)}
# {'average surface temperature': 42.0, 'date': datetime.datetime(2017, 10, 7, 0, 0)}
# {'average surface temperature': 41.0, 'date': datetime.datetime(2017, 10, 8, 0, 0)}
# {'average surface temperature': 39.0, 'date': datetime.datetime(2017, 12, 15, 0, 0)}
# {'average surface temperature': 52.73913043478261, 'date': datetime.datetime(2017, 9, 23, 0, 0)}
# {'average surface temperature': 44.0, 'date': datetime.datetime(2017, 10, 9, 0, 0)}
# {'average surface temperature': 47.0, 'date': datetime.datetime(2017, 7, 31, 0, 0)}
# {'average surface temperature': 58.611111111111114, 'date': datetime.datetime(2017, 5, 13, 0, 0)}
# {'average surface temperature': 38.0, 'date': datetime.datetime(2017, 10, 23, 0, 0)}
# {'average surface temperature': 51.25, 'date': datetime.datetime(2017, 10, 21, 0, 0)}
# {'average surface temperature': 44.0, 'date': datetime.datetime(2017, 12, 12, 0, 0)}
# {'average surface temperature': 56.0, 'date': datetime.datetime(2017, 10, 28, 0, 0)}
# {'average surface temperature': 51.70967741935484, 'date': datetime.datetime(2017, 5, 5, 0, 0)}
# {'average surface temperature': 53.333333333333336, 'date': datetime.datetime(2017, 10, 10, 0, 0)}
# {'average surface temperature': 46.291666666666664, 'date': datetime.datetime(2017, 4, 11, 0, 0)}
# {'average surface temperature': 58.0, 'date': datetime.datetime(2017, 8, 1, 0, 0)}
# {'average surface temperature': 51.0, 'date': datetime.datetime(2017, 3, 29, 0, 0)}
# {'average surface temperature': 59.375, 'date': datetime.datetime(2017, 4, 24, 0, 0)}
# {'average surface temperature': 51.857142857142854, 'date': datetime.datetime(2017, 6, 7, 0, 0)}
# {'average surface temperature': 45.5, 'date': datetime.datetime(2017, 11, 8, 0, 0)}
# {'average surface temperature': 44.0, 'date': datetime.datetime(2017, 10, 6, 0, 0)}
# {'average surface temperature': 61.3, 'date': datetime.datetime(2017, 11, 9, 0, 0)}
# {'average surface temperature': 44.6, 'date': datetime.datetime(2017, 10, 26, 0, 0)}
# {'average surface temperature': 43.0, 'date': datetime.datetime(2017, 9, 29, 0, 0)}
# {'average surface temperature': 50.6, 'date': datetime.datetime(2017, 12, 8, 0, 0)}
# {'average surface temperature': 60.0, 'date': datetime.datetime(2017, 12, 13, 0, 0)}
# {'average surface temperature': 56.291666666666664, 'date': datetime.datetime(2017, 5, 8, 0, 0)}
# {'average surface temperature': 39.666666666666664, 'date': datetime.datetime(2017, 5, 16, 0, 0)}
# {'average surface temperature': 44.333333333333336, 'date': datetime.datetime(2017, 6, 30, 0, 0)}
# {'average surface temperature': 46.0, 'date': datetime.datetime(2017, 12, 21, 0, 0)}
# {'average surface temperature': 62.75, 'date': datetime.datetime(2017, 12, 27, 0, 0)}
# {'average surface temperature': 45.2, 'date': datetime.datetime(2017, 4, 2, 0, 0)}
# {'average surface temperature': 54.0, 'date': datetime.datetime(2017, 12, 25, 0, 0)}
# {'average surface temperature': 48.25, 'date': datetime.datetime(2017, 10, 1, 0, 0)}
# {'average surface temperature': 46.0, 'date': datetime.datetime(2017, 12, 10, 0, 0)}
# {'average surface temperature': 52.0, 'date': datetime.datetime(2017, 11, 14, 0, 0)}
# {'average surface temperature': 66.0, 'date': datetime.datetime(2017, 3, 25, 0, 0)}
# {'average surface temperature': 58.5, 'date': datetime.datetime(2017, 11, 5, 0, 0)}
# {'average surface temperature': 49.714285714285715, 'date': datetime.datetime(2017, 9, 27, 0, 0)}
# {'average surface temperature': 46.0, 'date': datetime.datetime(2017, 6, 22, 0, 0)}
# {'average surface temperature': 51.5, 'date': datetime.datetime(2017, 5, 12, 0, 0)}
# {'average surface temperature': 57.8, 'date': datetime.datetime(2017, 12, 16, 0, 0)}
# {'average surface temperature': 60.625, 'date': datetime.datetime(2017, 11, 29, 0, 0)}
# {'average surface temperature': 59.36842105263158, 'date': datetime.datetime(2017, 5, 11, 0, 0)}
# {'average surface temperature': 52.41935483870968, 'date': datetime.datetime(2017, 11, 30, 0, 0)}
# {'average surface temperature': 60.75, 'date': datetime.datetime(2017, 4, 8, 0, 0)}
# {'average surface temperature': 48.0, 'date': datetime.datetime(2017, 7, 29, 0, 0)}
# {'average surface temperature': 53.25, 'date': datetime.datetime(2017, 6, 14, 0, 0)}
# {'average surface temperature': 64.0, 'date': datetime.datetime(2017, 3, 7, 0, 0)}
# {'average surface temperature': 42.0, 'date': datetime.datetime(2017, 11, 28, 0, 0)}
# {'average surface temperature': 44.142857142857146, 'date': datetime.datetime(2017, 5, 18, 0, 0)}
# {'average surface temperature': 36.0, 'date': datetime.datetime(2017, 10, 16, 0, 0)}
# {'average surface temperature': 62.57303370786517, 'date': datetime.datetime(2017, 4, 4, 0, 0)}
# {'average surface temperature': 41.0, 'date': datetime.datetime(2017, 6, 13, 0, 0)}
# {'average surface temperature': 54.0, 'date': datetime.datetime(2017, 6, 1, 0, 0)}
# {'average surface temperature': 79.33333333333333, 'date': datetime.datetime(2017, 3, 18, 0, 0)}
# {'average surface temperature': 32.0, 'date': datetime.datetime(2017, 12, 24, 0, 0)}
# {'average surface temperature': 59.0, 'date': datetime.datetime(2017, 11, 21, 0, 0)}
# {'average surface temperature': 46.666666666666664, 'date': datetime.datetime(2017, 3, 9, 0, 0)}
# {'average surface temperature': 52.166666666666664, 'date': datetime.datetime(2017, 10, 18, 0, 0)}
# {'average surface temperature': 61.5, 'date': datetime.datetime(2017, 11, 22, 0, 0)}
# {'average surface temperature': 50.4, 'date': datetime.datetime(2017, 10, 27, 0, 0)}
# {'average surface temperature': 53.0, 'date': datetime.datetime(2017, 11, 12, 0, 0)}
# {'average surface temperature': 57.529411764705884, 'date': datetime.datetime(2017, 5, 6, 0, 0)}
# {'average surface temperature': 71.16666666666667, 'date': datetime.datetime(2017, 6, 20, 0, 0)}
# {'average surface temperature': 70.0, 'date': datetime.datetime(2017, 12, 14, 0, 0)}
# {'average surface temperature': 50.0, 'date': datetime.datetime(2017, 10, 20, 0, 0)}
# {'average surface temperature': 48.72222222222222, 'date': datetime.datetime(2017, 4, 16, 0, 0)}
# {'average surface temperature': 58.8, 'date': datetime.datetime(2017, 11, 23, 0, 0)}
# {'average surface temperature': 47.0, 'date': datetime.datetime(2017, 11, 13, 0, 0)}
# {'average surface temperature': 72.66666666666667, 'date': datetime.datetime(2017, 10, 15, 0, 0)}
# {'average surface temperature': 46.25, 'date': datetime.datetime(2017, 11, 11, 0, 0)}
# {'average surface temperature': 33.0, 'date': datetime.datetime(2017, 9, 26, 0, 0)}
# {'average surface temperature': 45.0, 'date': datetime.datetime(2017, 9, 22, 0, 0)}
# {'average surface temperature': 54.484848484848484, 'date': datetime.datetime(2017, 5, 22, 0, 0)}
# {'average surface temperature': 68.4, 'date': datetime.datetime(2017, 5, 1, 0, 0)}
# {'average surface temperature': 51.6, 'date': datetime.datetime(2017, 10, 17, 0, 0)}
# {'average surface temperature': 63.6, 'date': datetime.datetime(2017, 9, 20, 0, 0)}
# {'average surface temperature': 56.5, 'date': datetime.datetime(2017, 9, 10, 0, 0)}
# {'average surface temperature': 40.8, 'date': datetime.datetime(2017, 8, 14, 0, 0)}
# {'average surface temperature': 49.0, 'date': datetime.datetime(2017, 8, 13, 0, 0)}
# {'average surface temperature': 63.0, 'date': datetime.datetime(2017, 8, 10, 0, 0)}
# {'average surface temperature': 53.142857142857146, 'date': datetime.datetime(2017, 4, 5, 0, 0)}
# {'average surface temperature': 63.5, 'date': datetime.datetime(2017, 8, 2, 0, 0)}
# {'average surface temperature': 53.57142857142857, 'date': datetime.datetime(2017, 9, 24, 0, 0)}
# {'average surface temperature': 56.0, 'date': datetime.datetime(2017, 7, 6, 0, 0)}
# {'average surface temperature': 53.950980392156865, 'date': datetime.datetime(2017, 5, 15, 0, 0)}
# {'average surface temperature': 51.5, 'date': datetime.datetime(2017, 3, 8, 0, 0)}
# {'average surface temperature': 45.0, 'date': datetime.datetime(2017, 7, 5, 0, 0)}
# {'average surface temperature': 65.6, 'date': datetime.datetime(2017, 3, 14, 0, 0)}
# {'average surface temperature': 51.2, 'date': datetime.datetime(2017, 5, 23, 0, 0)}
# {'average surface temperature': 40.0, 'date': datetime.datetime(2017, 7, 4, 0, 0)}
# {'average surface temperature': 53.89473684210526, 'date': datetime.datetime(2017, 4, 23, 0, 0)}
# {'average surface temperature': 43.5, 'date': datetime.datetime(2017, 7, 2, 0, 0)}
# {'average surface temperature': 41.5, 'date': datetime.datetime(2017, 7, 14, 0, 0)}
# {'average surface temperature': 42.0, 'date': datetime.datetime(2017, 6, 18, 0, 0)}
# {'average surface temperature': 30.5, 'date': datetime.datetime(2017, 7, 1, 0, 0)}
# {'average surface temperature': 50.0, 'date': datetime.datetime(2017, 10, 3, 0, 0)}
# {'average surface temperature': 42.5, 'date': datetime.datetime(2017, 6, 16, 0, 0)}
# {'average surface temperature': 41.5, 'date': datetime.datetime(2017, 6, 11, 0, 0)}
# {'average surface temperature': 58.25, 'date': datetime.datetime(2017, 12, 9, 0, 0)}
# {'average surface temperature': 49.0, 'date': datetime.datetime(2017, 6, 9, 0, 0)}
# {'average surface temperature': 40.5, 'date': datetime.datetime(2017, 9, 21, 0, 0)}
# {'average surface temperature': 52.22222222222222, 'date': datetime.datetime(2017, 6, 4, 0, 0)}
# {'average surface temperature': 47.0, 'date': datetime.datetime(2017, 6, 3, 0, 0)}
# {'average surface temperature': 47.72727272727273, 'date': datetime.datetime(2017, 6, 2, 0, 0)}
# {'average surface temperature': 49.5, 'date': datetime.datetime(2017, 5, 26, 0, 0)}
# {'average surface temperature': 56.88235294117647, 'date': datetime.datetime(2017, 3, 26, 0, 0)}
# {'average surface temperature': 49.0, 'date': datetime.datetime(2017, 5, 14, 0, 0)}
# {'average surface temperature': 40.333333333333336, 'date': datetime.datetime(2017, 5, 24, 0, 0)}
# {'average surface temperature': 52.0, 'date': datetime.datetime(2017, 5, 17, 0, 0)}
# {'average surface temperature': 52.86842105263158, 'date': datetime.datetime(2017, 5, 10, 0, 0)}
# {'average surface temperature': 52.69565217391305, 'date': datetime.datetime(2017, 4, 12, 0, 0)}
# {'average surface temperature': 42.46153846153846, 'date': datetime.datetime(2017, 5, 9, 0, 0)}
