# %% [markdown]
# # Task C. Processing Data Stream
# ## Simulating real-time data using Apache Kafka Producers  (CLIMATE DATA)
# ## Task C - 1(a) Event Producer 1

# %% [markdown]
# ### Importing Libraries and Reading the CSV

# %%
#importing required libraries
import csv  # to read the csv files
import random  #for random number generation
import json  #for json dumps
import time  #for sleep function
import datetime  #creating datetime deltas
from kafka import KafkaConsumer, KafkaProducer  # creating kafka producers and consumers

# %%
def read_csv(file_name):     #function to read the csv file and return the header and data
    header = []
    data = []
    with open(file_name, 'r') as f:
        reader = csv.reader(f)
        row_count = 0
        
        for row in reader:
            if(row_count == 0):
                header.extend(row)
            else:
                data.append(row)
            row_count += 1
    
    return header, data
 
header_list_climate, data_climate = read_csv('climate_streaming.csv')  #Header and data collected seperately

# %% [markdown]
# ### Kafka producer

# %%
#kafka producer, publish the message into kafka queue in given topic
def publish_message(producer_instance, topic_name, key, value): #Function to publish the randomly generated message
    try:
        #Converting Key and value to Bytes
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        #Creating instance
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        #Flushing
        producer_instance.flush()
        print('Message published successfully.')
    except Exception as ex:
        print('Exception in publishing message')
        print(str(ex))

# connects to running kafka instance at port 9092 locally
def connect_kafka_producer():
    _producer = None
    try:
         #connecting to localhost Kafka and the default port
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'], api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer

# %% [markdown]
# ### Creating Kafka Connection and Sending Random instance of Climate data
# * Using random number generator, randomly selecting a row in climate_streaming file and feeding into kafka producer.
#
# * Publish the messages with a key as `climate` and value as climate data one row at a time.

# %%
#kafka producer
#assigning senders
SENDER = 'event'
SENDER1 = 'event1'

while True:  
    rnd_num = random.randint(0,len(data_climate)-1)  #Create random numbers
    d = data_climate[rnd_num]  #Assign random data
    
    climate_dict = {}  #empty dictionary
    # assigning value to the dictionary
    climate_dict['location'] = {'type':"Point", 'coordinates':[float(d[0]),float(d[1])]}
    climate_dict['air_temperature'] = int(d[2])
    climate_dict['relative_humidity'] = float(d[3])
    climate_dict['windspeed_knots'] = float(d[4])
    climate_dict['max_wind_speed'] = float(d[5])
    climate_dict['precipitation'] = d[6]
    climate_dict['sender_id'] = SENDER if rnd_num%2 == 0 else SENDER1
    climate_dict['creation_time'] = str(datetime.datetime.now())
    climate_dict['topic'] = 'climate'  #Assigning the Source of data for future reference
    
    #send data to kafka
    kafka_producer = connect_kafka_producer()
    key = 'climate' 
    print(json.dumps(climate_dict))
    publish_message(kafka_producer, 'climate', key, json.dumps(climate_dict))
    
    time.sleep(5)  #wait 5 seconds
# Out:
# {"location": {"coordinates": [-36.0856, 144.233], "type": "Point"}, "sender_id": "event", "relative_humidity": 43.2, "topic": "climate", "windspeed_knots": 5.9, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:10:57.535827", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-37.229, 141.182], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.5, "topic": "climate", "windspeed_knots": 4.7, "precipitation": " 0.01G", "max_wind_speed": 7.0, "creation_time": "2019-05-23 10:11:03.050757", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-37.608, 149.282], "type": "Point"}, "sender_id": "event1", "relative_humidity": 62.7, "topic": "climate", "windspeed_knots": 7.6, "precipitation": " 0.00I", "max_wind_speed": 18.1, "creation_time": "2019-05-23 10:11:08.115707", "air_temperature": 22}
# Message published successfully.
# {"location": {"coordinates": [-37.61, 149.279], "type": "Point"}, "sender_id": "event1", "relative_humidity": 57.4, "topic": "climate", "windspeed_knots": 10.9, "precipitation": " 0.00I", "max_wind_speed": 22.0, "creation_time": "2019-05-23 10:11:13.158558", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-37.375, 148.054], "type": "Point"}, "sender_id": "event", "relative_humidity": 47.0, "topic": "climate", "windspeed_knots": 4.8, "precipitation": " 0.00I", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:11:18.184232", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-38.167, 143.841], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.1, "topic": "climate", "windspeed_knots": 5.3, "precipitation": " 0.00G", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:11:23.222812", "air_temperature": 21}
# Message published successfully.
# {"location": {"coordinates": [-36.6312, 142.5058], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.5, "topic": "climate", "windspeed_knots": 5.7, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:11:28.249074", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-36.575, 146.6668], "type": "Point"}, "sender_id": "event", "relative_humidity": 53.6, "topic": "climate", "windspeed_knots": 7.9, "precipitation": " 0.00G", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:11:33.353239", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-37.605, 149.302], "type": "Point"}, "sender_id": "event1", "relative_humidity": 54.4, "topic": "climate", "windspeed_knots": 5.7, "precipitation": " 0.00I", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:11:38.388822", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-37.858, 143.428], "type": "Point"}, "sender_id": "event", "relative_humidity": 50.4, "topic": "climate", "windspeed_knots": 7.9, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:11:43.441522", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-36.3114, 142.7605], "type": "Point"}, "sender_id": "event", "relative_humidity": 56.7, "topic": "climate", "windspeed_knots": 9.3, "precipitation": " 0.00I", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:11:48.497471", "air_temperature": 28}
# Message published successfully.
# {"location": {"coordinates": [-37.453, 148.111], "type": "Point"}, "sender_id": "event", "relative_humidity": 45.3, "topic": "climate", "windspeed_knots": 10.6, "precipitation": " 0.08G", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:11:53.519297", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-37.087, 145.363], "type": "Point"}, "sender_id": "event", "relative_humidity": 49.4, "topic": "climate", "windspeed_knots": 3.8, "precipitation": " 0.01G", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:11:58.559930", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-37.485, 148.095], "type": "Point"}, "sender_id": "event1", "relative_humidity": 45.4, "topic": "climate", "windspeed_knots": 5.2, "precipitation": " 0.00A", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:12:03.622028", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-37.467, 148.127], "type": "Point"}, "sender_id": "event", "relative_humidity": 37.9, "topic": "climate", "windspeed_knots": 8.5, "precipitation": " 0.02G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:12:08.674054", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-37.59, 149.31], "type": "Point"}, "sender_id": "event", "relative_humidity": 57.2, "topic": "climate", "windspeed_knots": 8.9, "precipitation": " 0.98G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:12:13.709910", "air_temperature": 19}
# Message published successfully.
# {"location": {"coordinates": [-36.6732, 142.5162], "type": "Point"}, "sender_id": "event", "relative_humidity": 53.9, "topic": "climate", "windspeed_knots": 8.3, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:12:18.758466", "air_temperature": 19}
# Message published successfully.
# {"location": {"coordinates": [-37.0884, 141.0357], "type": "Point"}, "sender_id": "event", "relative_humidity": 40.4, "topic": "climate", "windspeed_knots": 5.9, "precipitation": " 0.00G", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:12:23.796278", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-35.889, 145.614], "type": "Point"}, "sender_id": "event", "relative_humidity": 49.2, "topic": "climate", "windspeed_knots": 10.5, "precipitation": " 0.12G", "max_wind_speed": 20.0, "creation_time": "2019-05-23 10:12:28.837037", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-36.3756, 143.7243], "type": "Point"}, "sender_id": "event1", "relative_humidity": 47.1, "topic": "climate", "windspeed_knots": 8.1, "precipitation": " 0.01G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:12:33.891430", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-37.397, 148.121], "type": "Point"}, "sender_id": "event1", "relative_humidity": 44.0, "topic": "climate", "windspeed_knots": 13.6, "precipitation": " 0.04G", "max_wind_speed": 21.0, "creation_time": "2019-05-23 10:12:38.942282", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-38.127, 143.82], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.0, "topic": "climate", "windspeed_knots": 2.8, "precipitation": " 0.00I", "max_wind_speed": 8.0, "creation_time": "2019-05-23 10:12:43.997002", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-36.156, 143.568], "type": "Point"}, "sender_id": "event", "relative_humidity": 51.4, "topic": "climate", "windspeed_knots": 4.6, "precipitation": " 0.00I", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:12:49.039696", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-37.609, 149.32], "type": "Point"}, "sender_id": "event", "relative_humidity": 48.3, "topic": "climate", "windspeed_knots": 9.4, "precipitation": " 0.01G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:12:54.062818", "air_temperature": 16}
# Message published successfully.
# {"location": {"coordinates": [-36.273, 146.155], "type": "Point"}, "sender_id": "event1", "relative_humidity": 56.3, "topic": "climate", "windspeed_knots": 8.0, "precipitation": " 0.08G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:12:59.111297", "air_temperature": 22}
# Message published successfully.
# {"location": {"coordinates": [-37.397, 148.121], "type": "Point"}, "sender_id": "event1", "relative_humidity": 44.0, "topic": "climate", "windspeed_knots": 13.6, "precipitation": " 0.04G", "max_wind_speed": 21.0, "creation_time": "2019-05-23 10:13:04.198421", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-37.602, 149.311], "type": "Point"}, "sender_id": "event", "relative_humidity": 48.5, "topic": "climate", "windspeed_knots": 7.3, "precipitation": " 0.00G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:13:09.224990", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-37.463, 148.109], "type": "Point"}, "sender_id": "event1", "relative_humidity": 45.1, "topic": "climate", "windspeed_knots": 5.6, "precipitation": " 0.00I", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:13:14.274224", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-37.758, 148.721], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.2, "topic": "climate", "windspeed_knots": 9.8, "precipitation": " 0.00I", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:13:19.307287", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-36.851, 148.117], "type": "Point"}, "sender_id": "event", "relative_humidity": 45.3, "topic": "climate", "windspeed_knots": 2.5, "precipitation": " 0.00G", "max_wind_speed": 6.0, "creation_time": "2019-05-23 10:13:24.327260", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-38.498, 146.95], "type": "Point"}, "sender_id": "event1", "relative_humidity": 38.6, "topic": "climate", "windspeed_knots": 1.8, "precipitation": " 0.00I", "max_wind_speed": 5.1, "creation_time": "2019-05-23 10:13:29.368161", "air_temperature": 5}
# Message published successfully.
# {"location": {"coordinates": [-37.329, 143.136], "type": "Point"}, "sender_id": "event", "relative_humidity": 47.0, "topic": "climate", "windspeed_knots": 13.2, "precipitation": " 0.00I", "max_wind_speed": 20.0, "creation_time": "2019-05-23 10:13:34.389155", "air_temperature": 21}
# Message published successfully.
# {"location": {"coordinates": [-36.293, 146.148], "type": "Point"}, "sender_id": "event", "relative_humidity": 50.8, "topic": "climate", "windspeed_knots": 5.8, "precipitation": " 0.00I", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:13:39.432214", "air_temperature": 16}
# Message published successfully.
# {"location": {"coordinates": [-37.475, 148.134], "type": "Point"}, "sender_id": "event1", "relative_humidity": 43.1, "topic": "climate", "windspeed_knots": 3.4, "precipitation": " 0.00I", "max_wind_speed": 7.0, "creation_time": "2019-05-23 10:13:44.473678", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-35.6374, 142.3787], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.6, "topic": "climate", "windspeed_knots": 13.1, "precipitation": " 0.00I", "max_wind_speed": 18.1, "creation_time": "2019-05-23 10:13:49.495194", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-36.8948, 142.3282], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.2, "topic": "climate", "windspeed_knots": 6.7, "precipitation": " 0.01G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:13:54.515434", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-36.5775, 142.6076], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.7, "topic": "climate", "windspeed_knots": 5.5, "precipitation": " 0.28G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:13:59.535497", "air_temperature": 19}
# Message published successfully.
# {"location": {"coordinates": [-36.5775, 142.6076], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.7, "topic": "climate", "windspeed_knots": 5.5, "precipitation": " 0.28G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:14:04.556663", "air_temperature": 19}
# Message published successfully.
# {"location": {"coordinates": [-36.369, 143.7132], "type": "Point"}, "sender_id": "event", "relative_humidity": 50.1, "topic": "climate", "windspeed_knots": 8.5, "precipitation": " 0.08G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:14:09.577361", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-37.227, 141.151], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.2, "topic": "climate", "windspeed_knots": 10.0, "precipitation": " 0.02G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:14:14.653793", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-37.585, 149.336], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.5, "topic": "climate", "windspeed_knots": 6.7, "precipitation": " 0.00G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:14:19.700471", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-37.294, 141.232], "type": "Point"}, "sender_id": "event", "relative_humidity": 49.0, "topic": "climate", "windspeed_knots": 4.6, "precipitation": " 0.00G", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:14:24.744234", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-37.332, 143.375], "type": "Point"}, "sender_id": "event", "relative_humidity": 51.7, "topic": "climate", "windspeed_knots": 7.2, "precipitation": " 0.00I", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:14:29.787383", "air_temperature": 21}
# Message published successfully.
# {"location": {"coordinates": [-36.294, 146.149], "type": "Point"}, "sender_id": "event1", "relative_humidity": 57.7, "topic": "climate", "windspeed_knots": 9.9, "precipitation": " 0.00I", "max_wind_speed": 18.1, "creation_time": "2019-05-23 10:14:34.822232", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-37.621, 143.447], "type": "Point"}, "sender_id": "event1", "relative_humidity": 53.4, "topic": "climate", "windspeed_knots": 6.1, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:14:39.854491", "air_temperature": 23}
# Message published successfully.
# {"location": {"coordinates": [-37.0684, 141.0437], "type": "Point"}, "sender_id": "event", "relative_humidity": 51.1, "topic": "climate", "windspeed_knots": 6.0, "precipitation": " 0.12G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:14:44.903861", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-36.275, 142.785], "type": "Point"}, "sender_id": "event", "relative_humidity": 30.8, "topic": "climate", "windspeed_knots": 5.7, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:14:49.936702", "air_temperature": 6}
# Message published successfully.
# {"location": {"coordinates": [-37.0046, 141.8047], "type": "Point"}, "sender_id": "event", "relative_humidity": 41.4, "topic": "climate", "windspeed_knots": 6.9, "precipitation": " 0.00G", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:14:54.974233", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-36.0279, 146.0244], "type": "Point"}, "sender_id": "event", "relative_humidity": 60.1, "topic": "climate", "windspeed_knots": 8.0, "precipitation": " 0.12G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:14:59.997082", "air_temperature": 24}
# Message published successfully.
# {"location": {"coordinates": [-37.288, 144.39], "type": "Point"}, "sender_id": "event1", "relative_humidity": 49.9, "topic": "climate", "windspeed_knots": 6.1, "precipitation": " 0.02G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:15:05.032125", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-36.943, 143.286], "type": "Point"}, "sender_id": "event1", "relative_humidity": 55.2, "topic": "climate", "windspeed_knots": 5.8, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:15:10.081907", "air_temperature": 24}
# Message published successfully.
# {"location": {"coordinates": [-38.127, 143.82], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.0, "topic": "climate", "windspeed_knots": 2.8, "precipitation": " 0.00I", "max_wind_speed": 8.0, "creation_time": "2019-05-23 10:15:15.122263", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-37.591, 149.33], "type": "Point"}, "sender_id": "event1", "relative_humidity": 46.7, "topic": "climate", "windspeed_knots": 10.0, "precipitation": " 0.00I", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:15:20.165554", "air_temperature": 16}
# Message published successfully.
# {"location": {"coordinates": [-36.701, 142.538], "type": "Point"}, "sender_id": "event1", "relative_humidity": 61.5, "topic": "climate", "windspeed_knots": 5.5, "precipitation": " 0.28G", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:15:25.183512", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-36.9194, 143.6131], "type": "Point"}, "sender_id": "event", "relative_humidity": 50.3, "topic": "climate", "windspeed_knots": 7.7, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:15:30.203306", "air_temperature": 19}
# Message published successfully.
# {"location": {"coordinates": [-36.2111, 141.505], "type": "Point"}, "sender_id": "event1", "relative_humidity": 55.5, "topic": "climate", "windspeed_knots": 7.9, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:15:35.224090", "air_temperature": 24}
# Message published successfully.
# {"location": {"coordinates": [-37.588, 141.259], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.8, "topic": "climate", "windspeed_knots": 9.3, "precipitation": " 0.98G", "max_wind_speed": 18.1, "creation_time": "2019-05-23 10:15:40.235322", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-37.618, 143.0013], "type": "Point"}, "sender_id": "event1", "relative_humidity": 36.0, "topic": "climate", "windspeed_knots": 15.9, "precipitation": " 0.00I", "max_wind_speed": 22.0, "creation_time": "2019-05-23 10:15:45.252458", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-36.0005, 143.1847], "type": "Point"}, "sender_id": "event1", "relative_humidity": 52.5, "topic": "climate", "windspeed_knots": 7.7, "precipitation": " 0.00I", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:15:50.278033", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-37.8276, 142.7573], "type": "Point"}, "sender_id": "event1", "relative_humidity": 42.1, "topic": "climate", "windspeed_knots": 7.6, "precipitation": " 0.01G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:15:55.320312", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-37.6767, 142.9892], "type": "Point"}, "sender_id": "event1", "relative_humidity": 53.8, "topic": "climate", "windspeed_knots": 6.7, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:16:00.337750", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-37.062, 141.373], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.2, "topic": "climate", "windspeed_knots": 13.7, "precipitation": " 0.00I", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:16:05.361817", "air_temperature": 26}
# Message published successfully.
# {"location": {"coordinates": [-37.478, 148.117], "type": "Point"}, "sender_id": "event1", "relative_humidity": 43.9, "topic": "climate", "windspeed_knots": 11.2, "precipitation": " 0.12G", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:16:10.410582", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-37.329, 143.136], "type": "Point"}, "sender_id": "event", "relative_humidity": 47.0, "topic": "climate", "windspeed_knots": 13.2, "precipitation": " 0.00I", "max_wind_speed": 20.0, "creation_time": "2019-05-23 10:16:15.480789", "air_temperature": 21}
# Message published successfully.
# {"location": {"coordinates": [-36.059, 143.7718], "type": "Point"}, "sender_id": "event1", "relative_humidity": 53.8, "topic": "climate", "windspeed_knots": 6.4, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:16:20.524601", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-36.952, 144.972], "type": "Point"}, "sender_id": "event1", "relative_humidity": 57.3, "topic": "climate", "windspeed_knots": 5.4, "precipitation": " 0.00I", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:16:25.559282", "air_temperature": 21}
# Message published successfully.
# {"location": {"coordinates": [-37.6008, 143.0558], "type": "Point"}, "sender_id": "event1", "relative_humidity": 44.8, "topic": "climate", "windspeed_knots": 8.3, "precipitation": " 0.00I", "max_wind_speed": 19.0, "creation_time": "2019-05-23 10:16:30.587206", "air_temperature": 15}
# Message published successfully.
# {"location": {"coordinates": [-35.0889, 141.2419], "type": "Point"}, "sender_id": "event1", "relative_humidity": 44.4, "topic": "climate", "windspeed_knots": 7.8, "precipitation": " 0.00G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:16:35.625970", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-37.6, 149.297], "type": "Point"}, "sender_id": "event1", "relative_humidity": 53.4, "topic": "climate", "windspeed_knots": 10.9, "precipitation": " 0.00I", "max_wind_speed": 19.0, "creation_time": "2019-05-23 10:16:40.665995", "air_temperature": 22}
# Message published successfully.
# {"location": {"coordinates": [-36.827, 142.5446], "type": "Point"}, "sender_id": "event1", "relative_humidity": 39.3, "topic": "climate", "windspeed_knots": 4.7, "precipitation": " 0.02G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:16:45.696070", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-37.605, 149.302], "type": "Point"}, "sender_id": "event1", "relative_humidity": 54.4, "topic": "climate", "windspeed_knots": 5.7, "precipitation": " 0.00I", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:16:50.726355", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-37.6, 149.297], "type": "Point"}, "sender_id": "event1", "relative_humidity": 53.4, "topic": "climate", "windspeed_knots": 10.9, "precipitation": " 0.00I", "max_wind_speed": 19.0, "creation_time": "2019-05-23 10:16:55.772308", "air_temperature": 22}
# Message published successfully.
# {"location": {"coordinates": [-36.764, 144.165], "type": "Point"}, "sender_id": "event1", "relative_humidity": 52.4, "topic": "climate", "windspeed_knots": 6.7, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:17:00.821924", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-38.0427, 141.0271], "type": "Point"}, "sender_id": "event1", "relative_humidity": 52.9, "topic": "climate", "windspeed_knots": 8.1, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:17:05.850892", "air_temperature": 19}
# Message published successfully.
# {"location": {"coordinates": [-36.1002, 142.3405], "type": "Point"}, "sender_id": "event1", "relative_humidity": 49.6, "topic": "climate", "windspeed_knots": 6.3, "precipitation": " 0.00I", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:17:10.866503", "air_temperature": 23}
# Message published successfully.
# {"location": {"coordinates": [-36.942, 143.282], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.3, "topic": "climate", "windspeed_knots": 7.1, "precipitation": " 0.00I", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:17:15.893740", "air_temperature": 25}
# Message published successfully.
# {"location": {"coordinates": [-36.758, 145.19], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.4, "topic": "climate", "windspeed_knots": 6.1, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:17:20.927218", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-34.965, 142.031], "type": "Point"}, "sender_id": "event", "relative_humidity": 62.6, "topic": "climate", "windspeed_knots": 10.1, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:17:25.947174", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-37.242, 141.153], "type": "Point"}, "sender_id": "event", "relative_humidity": 42.8, "topic": "climate", "windspeed_knots": 12.1, "precipitation": " 0.04G", "max_wind_speed": 19.0, "creation_time": "2019-05-23 10:17:30.963181", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-37.6836, 142.6069], "type": "Point"}, "sender_id": "event1", "relative_humidity": 38.4, "topic": "climate", "windspeed_knots": 11.5, "precipitation": " 0.00G", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:17:35.980135", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-37.375, 148.054], "type": "Point"}, "sender_id": "event", "relative_humidity": 47.0, "topic": "climate", "windspeed_knots": 4.8, "precipitation": " 0.00I", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:17:40.995930", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-36.6686, 142.5195], "type": "Point"}, "sender_id": "event1", "relative_humidity": 47.0, "topic": "climate", "windspeed_knots": 12.0, "precipitation": " 0.00I", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:17:46.011165", "air_temperature": 16}
# Message published successfully.
# {"location": {"coordinates": [-37.229, 141.182], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.5, "topic": "climate", "windspeed_knots": 4.7, "precipitation": " 0.01G", "max_wind_speed": 7.0, "creation_time": "2019-05-23 10:17:51.031463", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-35.323, 143.509], "type": "Point"}, "sender_id": "event1", "relative_humidity": 49.3, "topic": "climate", "windspeed_knots": 3.6, "precipitation": " 0.00I", "max_wind_speed": 7.0, "creation_time": "2019-05-23 10:17:56.046944", "air_temperature": 15}
# Message published successfully.
# {"location": {"coordinates": [-37.6745, 142.9848], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.5, "topic": "climate", "windspeed_knots": 10.2, "precipitation": " 0.00G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:18:01.080275", "air_temperature": 15}
# Message published successfully.
# {"location": {"coordinates": [-36.8264, 142.6138], "type": "Point"}, "sender_id": "event1", "relative_humidity": 48.2, "topic": "climate", "windspeed_knots": 14.7, "precipitation": " 0.43G", "max_wind_speed": 25.1, "creation_time": "2019-05-23 10:18:06.115689", "air_temperature": 15}
# Message published successfully.
# {"location": {"coordinates": [-36.8741, 143.91], "type": "Point"}, "sender_id": "event", "relative_humidity": 41.9, "topic": "climate", "windspeed_knots": 9.2, "precipitation": " 0.12G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:18:11.150449", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-35.0889, 141.2419], "type": "Point"}, "sender_id": "event1", "relative_humidity": 44.4, "topic": "climate", "windspeed_knots": 7.8, "precipitation": " 0.00G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:18:16.181935", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-37.444, 148.101], "type": "Point"}, "sender_id": "event", "relative_humidity": 42.0, "topic": "climate", "windspeed_knots": 4.6, "precipitation": " 0.00I", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:18:21.227566", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-36.943, 143.286], "type": "Point"}, "sender_id": "event1", "relative_humidity": 55.2, "topic": "climate", "windspeed_knots": 5.8, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:18:26.281009", "air_temperature": 24}
# Message published successfully.
# {"location": {"coordinates": [-36.1704, 144.0433], "type": "Point"}, "sender_id": "event", "relative_humidity": 41.7, "topic": "climate", "windspeed_knots": 8.7, "precipitation": " 0.00I", "max_wind_speed": 19.0, "creation_time": "2019-05-23 10:18:31.295919", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-36.3328, 146.0355], "type": "Point"}, "sender_id": "event", "relative_humidity": 37.2, "topic": "climate", "windspeed_knots": 6.2, "precipitation": " 0.08G", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:18:36.339069", "air_temperature": 7}
# Message published successfully.
# {"location": {"coordinates": [-36.6516, 141.4943], "type": "Point"}, "sender_id": "event", "relative_humidity": 45.3, "topic": "climate", "windspeed_knots": 8.5, "precipitation": " 0.00G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:18:41.356897", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-36.098, 143.74], "type": "Point"}, "sender_id": "event", "relative_humidity": 59.3, "topic": "climate", "windspeed_knots": 4.2, "precipitation": " 0.01G", "max_wind_speed": 7.0, "creation_time": "2019-05-23 10:18:46.396708", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-37.389, 149.311], "type": "Point"}, "sender_id": "event", "relative_humidity": 53.0, "topic": "climate", "windspeed_knots": 6.6, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:18:51.423509", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-37.0046, 141.8047], "type": "Point"}, "sender_id": "event", "relative_humidity": 41.4, "topic": "climate", "windspeed_knots": 6.9, "precipitation": " 0.00G", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:18:56.436531", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-37.497, 147.266], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.0, "topic": "climate", "windspeed_knots": 14.1, "precipitation": " 0.02G", "max_wind_speed": 20.0, "creation_time": "2019-05-23 10:19:01.452904", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-38.498, 146.95], "type": "Point"}, "sender_id": "event1", "relative_humidity": 38.6, "topic": "climate", "windspeed_knots": 1.8, "precipitation": " 0.00I", "max_wind_speed": 5.1, "creation_time": "2019-05-23 10:19:06.469934", "air_temperature": 5}
# Message published successfully.
# {"location": {"coordinates": [-36.2669, 143.1906], "type": "Point"}, "sender_id": "event", "relative_humidity": 42.7, "topic": "climate", "windspeed_knots": 10.0, "precipitation": " 0.01G", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:19:11.519331", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-35.937, 145.607], "type": "Point"}, "sender_id": "event1", "relative_humidity": 43.3, "topic": "climate", "windspeed_knots": 2.6, "precipitation": " 0.00I", "max_wind_speed": 7.0, "creation_time": "2019-05-23 10:19:16.532448", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-36.294, 146.149], "type": "Point"}, "sender_id": "event1", "relative_humidity": 57.7, "topic": "climate", "windspeed_knots": 9.9, "precipitation": " 0.00I", "max_wind_speed": 18.1, "creation_time": "2019-05-23 10:19:21.567715", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-35.953, 141.078], "type": "Point"}, "sender_id": "event", "relative_humidity": 47.2, "topic": "climate", "windspeed_knots": 8.8, "precipitation": " 0.00G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:19:26.583953", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-37.091, 145.362], "type": "Point"}, "sender_id": "event1", "relative_humidity": 48.8, "topic": "climate", "windspeed_knots": 4.2, "precipitation": " 0.00I", "max_wind_speed": 7.0, "creation_time": "2019-05-23 10:19:31.618660", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-37.4437, 143.4924], "type": "Point"}, "sender_id": "event1", "relative_humidity": 50.7, "topic": "climate", "windspeed_knots": 6.1, "precipitation": " 0.00I", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:19:36.643376", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-37.229, 141.182], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.5, "topic": "climate", "windspeed_knots": 4.7, "precipitation": " 0.01G", "max_wind_speed": 7.0, "creation_time": "2019-05-23 10:19:41.657082", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-37.633, 149.264], "type": "Point"}, "sender_id": "event1", "relative_humidity": 50.9, "topic": "climate", "windspeed_knots": 12.9, "precipitation": " 0.03G", "max_wind_speed": 21.0, "creation_time": "2019-05-23 10:19:46.688076", "air_temperature": 16}
# Message published successfully.
# {"location": {"coordinates": [-36.3769, 144.7505], "type": "Point"}, "sender_id": "event", "relative_humidity": 50.9, "topic": "climate", "windspeed_knots": 5.9, "precipitation": " 0.00I", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:19:51.712166", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-37.376, 148.042], "type": "Point"}, "sender_id": "event1", "relative_humidity": 43.2, "topic": "climate", "windspeed_knots": 5.5, "precipitation": " 0.00G", "max_wind_speed": 8.0, "creation_time": "2019-05-23 10:19:56.742383", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-37.7052, 144.6926], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.7, "topic": "climate", "windspeed_knots": 7.7, "precipitation": " 0.00G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:20:01.775325", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-36.759, 144.158], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.5, "topic": "climate", "windspeed_knots": 7.0, "precipitation": " 0.00G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:20:06.784984", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-34.965, 142.031], "type": "Point"}, "sender_id": "event", "relative_humidity": 62.6, "topic": "climate", "windspeed_knots": 10.1, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:20:11.825221", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-37.6593, 143.3445], "type": "Point"}, "sender_id": "event1", "relative_humidity": 40.1, "topic": "climate", "windspeed_knots": 12.1, "precipitation": " 0.08G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:20:16.872904", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-36.1, 143.767], "type": "Point"}, "sender_id": "event1", "relative_humidity": 53.5, "topic": "climate", "windspeed_knots": 7.2, "precipitation": " 0.31G", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:20:21.892594", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-36.6312, 142.5058], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.5, "topic": "climate", "windspeed_knots": 5.7, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:20:26.922463", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-37.58, 149.331], "type": "Point"}, "sender_id": "event1", "relative_humidity": 59.0, "topic": "climate", "windspeed_knots": 6.0, "precipitation": " 0.00I", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:20:31.966098", "air_temperature": 23}
# Message published successfully.
# {"location": {"coordinates": [-37.598, 149.29], "type": "Point"}, "sender_id": "event1", "relative_humidity": 53.5, "topic": "climate", "windspeed_knots": 8.8, "precipitation": " 0.00I", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:20:36.999292", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-38.495, 146.944], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.6, "topic": "climate", "windspeed_knots": 3.9, "precipitation": " 0.39G", "max_wind_speed": 8.0, "creation_time": "2019-05-23 10:20:42.037125", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-37.247, 141.278], "type": "Point"}, "sender_id": "event", "relative_humidity": 47.4, "topic": "climate", "windspeed_knots": 7.1, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:20:47.061625", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-36.273, 146.155], "type": "Point"}, "sender_id": "event1", "relative_humidity": 56.3, "topic": "climate", "windspeed_knots": 8.0, "precipitation": " 0.08G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:20:52.083254", "air_temperature": 22}
# Message published successfully.
# {"location": {"coordinates": [-37.618, 149.281], "type": "Point"}, "sender_id": "event1", "relative_humidity": 53.8, "topic": "climate", "windspeed_knots": 9.2, "precipitation": " 0.02G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:20:57.127053", "air_temperature": 19}
# Message published successfully.
# {"location": {"coordinates": [-37.327, 148.083], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.8, "topic": "climate", "windspeed_knots": 8.8, "precipitation": " 0.39G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:21:02.147156", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-36.6851, 141.6125], "type": "Point"}, "sender_id": "event", "relative_humidity": 59.0, "topic": "climate", "windspeed_knots": 9.4, "precipitation": " 0.75G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:21:07.162679", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-36.942, 143.292], "type": "Point"}, "sender_id": "event1", "relative_humidity": 51.1, "topic": "climate", "windspeed_knots": 8.1, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:21:12.198869", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-37.692, 143.593], "type": "Point"}, "sender_id": "event1", "relative_humidity": 45.8, "topic": "climate", "windspeed_knots": 6.5, "precipitation": " 0.00G", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:21:17.215320", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-36.152, 143.578], "type": "Point"}, "sender_id": "event1", "relative_humidity": 56.1, "topic": "climate", "windspeed_knots": 5.1, "precipitation": " 0.00I", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:21:22.248155", "air_temperature": 15}
# Message published successfully.
# {"location": {"coordinates": [-37.618, 143.0013], "type": "Point"}, "sender_id": "event1", "relative_humidity": 36.0, "topic": "climate", "windspeed_knots": 15.9, "precipitation": " 0.00I", "max_wind_speed": 22.0, "creation_time": "2019-05-23 10:21:27.264127", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-37.459, 148.092], "type": "Point"}, "sender_id": "event1", "relative_humidity": 48.5, "topic": "climate", "windspeed_knots": 7.1, "precipitation": " 0.00G", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:21:32.275988", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-36.5243, 142.0839], "type": "Point"}, "sender_id": "event1", "relative_humidity": 43.9, "topic": "climate", "windspeed_knots": 5.7, "precipitation": " 0.00G", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:21:37.300549", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-37.61, 149.279], "type": "Point"}, "sender_id": "event1", "relative_humidity": 57.4, "topic": "climate", "windspeed_knots": 10.9, "precipitation": " 0.00I", "max_wind_speed": 22.0, "creation_time": "2019-05-23 10:21:42.335640", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-37.497, 147.266], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.0, "topic": "climate", "windspeed_knots": 14.1, "precipitation": " 0.02G", "max_wind_speed": 20.0, "creation_time": "2019-05-23 10:21:47.348095", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-36.418, 141.596], "type": "Point"}, "sender_id": "event1", "relative_humidity": 50.1, "topic": "climate", "windspeed_knots": 8.7, "precipitation": " 0.00G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:21:52.379921", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-37.758, 148.721], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.2, "topic": "climate", "windspeed_knots": 9.8, "precipitation": " 0.00I", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:21:57.413851", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-36.0459, 143.8907], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.7, "topic": "climate", "windspeed_knots": 7.8, "precipitation": " 0.00I", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:22:02.443084", "air_temperature": 21}
# Message published successfully.
# {"location": {"coordinates": [-37.238, 141.145], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.6, "topic": "climate", "windspeed_knots": 8.3, "precipitation": " 0.24G", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:22:07.472092", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-37.437, 148.104], "type": "Point"}, "sender_id": "event1", "relative_humidity": 40.7, "topic": "climate", "windspeed_knots": 16.7, "precipitation": " 0.12G", "max_wind_speed": 21.0, "creation_time": "2019-05-23 10:22:12.539653", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-37.583, 149.316], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.3, "topic": "climate", "windspeed_knots": 12.2, "precipitation": " 0.04G", "max_wind_speed": 22.0, "creation_time": "2019-05-23 10:22:17.556954", "air_temperature": 25}
# Message published successfully.
# {"location": {"coordinates": [-37.749, 148.297], "type": "Point"}, "sender_id": "event1", "relative_humidity": 52.6, "topic": "climate", "windspeed_knots": 10.3, "precipitation": " 0.00G", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:22:22.571524", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-37.61, 149.296], "type": "Point"}, "sender_id": "event", "relative_humidity": 48.3, "topic": "climate", "windspeed_knots": 14.4, "precipitation": " 0.00G", "max_wind_speed": 19.0, "creation_time": "2019-05-23 10:22:27.583198", "air_temperature": 16}
# Message published successfully.
# {"location": {"coordinates": [-37.0046, 141.8047], "type": "Point"}, "sender_id": "event", "relative_humidity": 41.4, "topic": "climate", "windspeed_knots": 6.9, "precipitation": " 0.00G", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:22:32.613499", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-37.608, 149.292], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.6, "topic": "climate", "windspeed_knots": 9.7, "precipitation": " 0.02G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:22:37.650313", "air_temperature": 15}
# Message published successfully.
# {"location": {"coordinates": [-36.8867, 142.1873], "type": "Point"}, "sender_id": "event", "relative_humidity": 39.3, "topic": "climate", "windspeed_knots": 17.7, "precipitation": " 0.01G", "max_wind_speed": 30.9, "creation_time": "2019-05-23 10:22:42.687561", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-37.462, 148.089], "type": "Point"}, "sender_id": "event1", "relative_humidity": 40.7, "topic": "climate", "windspeed_knots": 5.3, "precipitation": " 0.00G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:22:47.715654", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-37.1104, 141.828], "type": "Point"}, "sender_id": "event1", "relative_humidity": 46.2, "topic": "climate", "windspeed_knots": 10.5, "precipitation": " 0.28G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:22:52.747409", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-36.834, 142.524], "type": "Point"}, "sender_id": "event", "relative_humidity": 50.3, "topic": "climate", "windspeed_knots": 8.6, "precipitation": " 0.02G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:22:57.762467", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-36.0279, 146.0244], "type": "Point"}, "sender_id": "event", "relative_humidity": 60.1, "topic": "climate", "windspeed_knots": 8.0, "precipitation": " 0.12G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:23:02.798492", "air_temperature": 24}
# Message published successfully.
# {"location": {"coordinates": [-38.495, 146.944], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.6, "topic": "climate", "windspeed_knots": 3.9, "precipitation": " 0.39G", "max_wind_speed": 8.0, "creation_time": "2019-05-23 10:23:07.834556", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-36.779, 146.108], "type": "Point"}, "sender_id": "event", "relative_humidity": 42.0, "topic": "climate", "windspeed_knots": 11.4, "precipitation": " 0.00G", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:23:12.868476", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-36.4325, 144.3142], "type": "Point"}, "sender_id": "event1", "relative_humidity": 61.0, "topic": "climate", "windspeed_knots": 9.3, "precipitation": " 0.20G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:23:17.897905", "air_temperature": 26}
# Message published successfully.
# {"location": {"coordinates": [-37.297, 144.384], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.8, "topic": "climate", "windspeed_knots": 9.1, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:23:22.909439", "air_temperature": 22}
# Message published successfully.
# {"location": {"coordinates": [-37.9243, 144.1064], "type": "Point"}, "sender_id": "event", "relative_humidity": 53.0, "topic": "climate", "windspeed_knots": 14.6, "precipitation": " 0.00I", "max_wind_speed": 22.9, "creation_time": "2019-05-23 10:23:27.926345", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-36.275, 146.154], "type": "Point"}, "sender_id": "event", "relative_humidity": 53.3, "topic": "climate", "windspeed_knots": 7.9, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:23:32.966648", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-37.245, 143.426], "type": "Point"}, "sender_id": "event", "relative_humidity": 47.0, "topic": "climate", "windspeed_knots": 5.2, "precipitation": " 0.00I", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:23:37.999324", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-36.765, 144.176], "type": "Point"}, "sender_id": "event", "relative_humidity": 54.9, "topic": "climate", "windspeed_knots": 5.9, "precipitation": " 0.00I", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:23:43.030257", "air_temperature": 16}
# ...
# Message published successfully.
# {"location": {"coordinates": [-37.389, 149.311], "type": "Point"}, "sender_id": "event", "relative_humidity": 53.0, "topic": "climate", "windspeed_knots": 6.6, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:28:14.690475", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-38.16, 143.803], "type": "Point"}, "sender_id": "event1", "relative_humidity": 62.2, "topic": "climate", "windspeed_knots": 7.1, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:28:19.726454", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-37.591, 149.33], "type": "Point"}, "sender_id": "event1", "relative_humidity": 46.7, "topic": "climate", "windspeed_knots": 10.0, "precipitation": " 0.00I", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:28:24.754877", "air_temperature": 16}
# Message published successfully.
# {"location": {"coordinates": [-37.247, 141.27], "type": "Point"}, "sender_id": "event", "relative_humidity": 43.1, "topic": "climate", "windspeed_knots": 4.7, "precipitation": " 0.00G", "max_wind_speed": 8.0, "creation_time": "2019-05-23 10:28:29.789333", "air_temperature": 10}
# Message published successfully.
# {"location": {"coordinates": [-37.6, 149.297], "type": "Point"}, "sender_id": "event1", "relative_humidity": 53.4, "topic": "climate", "windspeed_knots": 10.9, "precipitation": " 0.00I", "max_wind_speed": 19.0, "creation_time": "2019-05-23 10:28:34.827324", "air_temperature": 22}
# Message published successfully.
# {"location": {"coordinates": [-36.5871, 144.961], "type": "Point"}, "sender_id": "event", "relative_humidity": 43.6, "topic": "climate", "windspeed_knots": 9.0, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:28:39.839404", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-36.9817, 143.5051], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.0, "topic": "climate", "windspeed_knots": 14.4, "precipitation": " 0.16G", "max_wind_speed": 23.9, "creation_time": "2019-05-23 10:28:44.852606", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-36.096, 146.5016], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.0, "topic": "climate", "windspeed_knots": 12.9, "precipitation": " 0.16G", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:28:49.876017", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-36.6516, 141.4943], "type": "Point"}, "sender_id": "event", "relative_humidity": 45.3, "topic": "climate", "windspeed_knots": 8.5, "precipitation": " 0.00G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:28:54.897377", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-37.7052, 144.6926], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.7, "topic": "climate", "windspeed_knots": 7.7, "precipitation": " 0.00G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:28:59.914931", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-37.062, 141.373], "type": "Point"}, "sender_id": "event1", "relative_humidity": 46.8, "topic": "climate", "windspeed_knots": 8.0, "precipitation": " 0.00I", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:29:04.947166", "air_temperature": 22}
# Message published successfully.
# {"location": {"coordinates": [-37.363, 148.06], "type": "Point"}, "sender_id": "event", "relative_humidity": 35.3, "topic": "climate", "windspeed_knots": 18.2, "precipitation": " 0.00I", "max_wind_speed": 25.1, "creation_time": "2019-05-23 10:29:09.959786", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-36.273, 146.155], "type": "Point"}, "sender_id": "event1", "relative_humidity": 56.3, "topic": "climate", "windspeed_knots": 8.0, "precipitation": " 0.08G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:29:14.997525", "air_temperature": 22}
# Message published successfully.
# {"location": {"coordinates": [-36.4553, 142.8786], "type": "Point"}, "sender_id": "event1", "relative_humidity": 55.3, "topic": "climate", "windspeed_knots": 6.2, "precipitation": " 0.00I", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:29:20.063649", "air_temperature": 19}
# Message published successfully.
# {"location": {"coordinates": [-36.346, 143.631], "type": "Point"}, "sender_id": "event", "relative_humidity": 47.2, "topic": "climate", "windspeed_knots": 4.9, "precipitation": " 0.00I", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:29:25.099364", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-37.608, 149.292], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.6, "topic": "climate", "windspeed_knots": 9.7, "precipitation": " 0.02G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:29:30.142381", "air_temperature": 15}
# Message published successfully.
# {"location": {"coordinates": [-37.9072, 141.9183], "type": "Point"}, "sender_id": "event1", "relative_humidity": 43.3, "topic": "climate", "windspeed_knots": 7.0, "precipitation": " 0.00G", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:29:35.177764", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-38.231, 147.172], "type": "Point"}, "sender_id": "event1", "relative_humidity": 61.6, "topic": "climate", "windspeed_knots": 7.7, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:29:40.209380", "air_temperature": 24}
# Message published successfully.
# {"location": {"coordinates": [-37.9072, 141.9183], "type": "Point"}, "sender_id": "event1", "relative_humidity": 43.3, "topic": "climate", "windspeed_knots": 7.0, "precipitation": " 0.00G", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:29:45.241922", "air_temperature": 12}
# Message published successfully.
# {"location": {"coordinates": [-36.2032, 145.3025], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.0, "topic": "climate", "windspeed_knots": 7.1, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:29:50.276063", "air_temperature": 18}
# Message published successfully.
# {"location": {"coordinates": [-37.7052, 144.6926], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.7, "topic": "climate", "windspeed_knots": 7.7, "precipitation": " 0.00G", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:29:55.307186", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-36.404, 142.5467], "type": "Point"}, "sender_id": "event1", "relative_humidity": 60.9, "topic": "climate", "windspeed_knots": 6.3, "precipitation": " 0.00I", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:30:00.341740", "air_temperature": 25}
# Message published successfully.
# {"location": {"coordinates": [-38.141, 143.183], "type": "Point"}, "sender_id": "event", "relative_humidity": 54.1, "topic": "climate", "windspeed_knots": 5.7, "precipitation": " 0.00I", "max_wind_speed": 14.0, "creation_time": "2019-05-23 10:30:05.377725", "air_temperature": 23}
# Message published successfully.
# {"location": {"coordinates": [-36.5775, 142.6076], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.7, "topic": "climate", "windspeed_knots": 5.5, "precipitation": " 0.28G", "max_wind_speed": 12.0, "creation_time": "2019-05-23 10:30:10.407536", "air_temperature": 19}
# Message published successfully.
# {"location": {"coordinates": [-36.748, 144.168], "type": "Point"}, "sender_id": "event", "relative_humidity": 48.2, "topic": "climate", "windspeed_knots": 10.8, "precipitation": " 0.59G", "max_wind_speed": 22.9, "creation_time": "2019-05-23 10:30:15.424083", "air_temperature": 11}
# Message published successfully.
# {"location": {"coordinates": [-37.5268, 143.0551], "type": "Point"}, "sender_id": "event", "relative_humidity": 35.0, "topic": "climate", "windspeed_knots": 14.4, "precipitation": " 0.00G", "max_wind_speed": 20.0, "creation_time": "2019-05-23 10:30:20.439933", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-36.6312, 142.5058], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.5, "topic": "climate", "windspeed_knots": 5.7, "precipitation": " 0.00I", "max_wind_speed": 11.1, "creation_time": "2019-05-23 10:30:25.455733", "air_temperature": 17}
# Message published successfully.
# {"location": {"coordinates": [-36.9817, 143.5051], "type": "Point"}, "sender_id": "event", "relative_humidity": 44.0, "topic": "climate", "windspeed_knots": 14.4, "precipitation": " 0.16G", "max_wind_speed": 23.9, "creation_time": "2019-05-23 10:30:30.473743", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-37.758, 144.693], "type": "Point"}, "sender_id": "event1", "relative_humidity": 58.8, "topic": "climate", "windspeed_knots": 11.5, "precipitation": " 0.00I", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:30:35.489688", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-37.61, 149.296], "type": "Point"}, "sender_id": "event", "relative_humidity": 48.3, "topic": "climate", "windspeed_knots": 14.4, "precipitation": " 0.00G", "max_wind_speed": 19.0, "creation_time": "2019-05-23 10:30:40.506190", "air_temperature": 16}
# Message published successfully.
# {"location": {"coordinates": [-37.3847, 142.8935], "type": "Point"}, "sender_id": "event", "relative_humidity": 43.6, "topic": "climate", "windspeed_knots": 10.3, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:30:45.539166", "air_temperature": 20}
# Message published successfully.
# {"location": {"coordinates": [-36.2111, 141.505], "type": "Point"}, "sender_id": "event1", "relative_humidity": 55.5, "topic": "climate", "windspeed_knots": 7.9, "precipitation": " 0.00I", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:30:50.563850", "air_temperature": 24}
# Message published successfully.
# {"location": {"coordinates": [-37.5268, 143.0551], "type": "Point"}, "sender_id": "event", "relative_humidity": 35.0, "topic": "climate", "windspeed_knots": 14.4, "precipitation": " 0.00G", "max_wind_speed": 20.0, "creation_time": "2019-05-23 10:30:55.579355", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-36.942, 143.282], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.3, "topic": "climate", "windspeed_knots": 7.1, "precipitation": " 0.00I", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:31:00.592488", "air_temperature": 25}
# Message published successfully.
# {"location": {"coordinates": [-36.3328, 146.0355], "type": "Point"}, "sender_id": "event", "relative_humidity": 37.2, "topic": "climate", "windspeed_knots": 6.2, "precipitation": " 0.08G", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:31:05.625949", "air_temperature": 7}
# Message published successfully.
# {"location": {"coordinates": [-36.404, 142.5467], "type": "Point"}, "sender_id": "event1", "relative_humidity": 60.9, "topic": "climate", "windspeed_knots": 6.3, "precipitation": " 0.00I", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:31:10.668321", "air_temperature": 25}
# Message published successfully.
# {"location": {"coordinates": [-37.559, 148.037], "type": "Point"}, "sender_id": "event1", "relative_humidity": 41.1, "topic": "climate", "windspeed_knots": 12.7, "precipitation": " 0.24G", "max_wind_speed": 19.0, "creation_time": "2019-05-23 10:31:15.701107", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-37.562, 148.05], "type": "Point"}, "sender_id": "event1", "relative_humidity": 40.5, "topic": "climate", "windspeed_knots": 3.1, "precipitation": " 0.00I", "max_wind_speed": 8.0, "creation_time": "2019-05-23 10:31:20.732216", "air_temperature": 7}
# Message published successfully.
# {"location": {"coordinates": [-36.759, 144.158], "type": "Point"}, "sender_id": "event", "relative_humidity": 52.5, "topic": "climate", "windspeed_knots": 7.0, "precipitation": " 0.00G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:31:25.759320", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-37.606, 149.312], "type": "Point"}, "sender_id": "event1", "relative_humidity": 51.0, "topic": "climate", "windspeed_knots": 6.0, "precipitation": " 0.00G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:31:30.791078", "air_temperature": 16}
# Message published successfully.
# {"location": {"coordinates": [-37.386, 148.043], "type": "Point"}, "sender_id": "event1", "relative_humidity": 43.3, "topic": "climate", "windspeed_knots": 3.9, "precipitation": " 0.00I", "max_wind_speed": 8.0, "creation_time": "2019-05-23 10:31:35.828465", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-36.418, 141.596], "type": "Point"}, "sender_id": "event1", "relative_humidity": 50.1, "topic": "climate", "windspeed_knots": 8.7, "precipitation": " 0.00G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:31:40.871248", "air_temperature": 14}
# Message published successfully.
# {"location": {"coordinates": [-37.434, 148.091], "type": "Point"}, "sender_id": "event", "relative_humidity": 40.0, "topic": "climate", "windspeed_knots": 8.6, "precipitation": " 0.00G", "max_wind_speed": 15.0, "creation_time": "2019-05-23 10:31:45.904560", "air_temperature": 9}
# Message published successfully.
# {"location": {"coordinates": [-37.6836, 142.6069], "type": "Point"}, "sender_id": "event1", "relative_humidity": 38.4, "topic": "climate", "windspeed_knots": 11.5, "precipitation": " 0.00G", "max_wind_speed": 16.9, "creation_time": "2019-05-23 10:31:50.927592", "air_temperature": 13}
# Message published successfully.
# {"location": {"coordinates": [-37.1875, 146.8024], "type": "Point"}, "sender_id": "event", "relative_humidity": 58.3, "topic": "climate", "windspeed_knots": 9.3, "precipitation": " 0.00I", "max_wind_speed": 15.9, "creation_time": "2019-05-23 10:31:55.947153", "air_temperature": 28}
# Message published successfully.
# {"location": {"coordinates": [-37.538, 148.895], "type": "Point"}, "sender_id": "event1", "relative_humidity": 37.1, "topic": "climate", "windspeed_knots": 5.8, "precipitation": " 0.00I", "max_wind_speed": 9.9, "creation_time": "2019-05-23 10:32:00.968270", "air_temperature": 6}
# Message published successfully.
# {"location": {"coordinates": [-36.827, 142.5446], "type": "Point"}, "sender_id": "event1", "relative_humidity": 39.3, "topic": "climate", "windspeed_knots": 4.7, "precipitation": " 0.02G", "max_wind_speed": 13.0, "creation_time": "2019-05-23 10:32:05.999305", "air_temperature": 8}
# Message published successfully.
# {"location": {"coordinates": [-37.864, 144.174], "type": "Point"}, "sender_id": "event1", "relative_humidity": 58.4, "topic": "climate", "windspeed_knots": 11.9, "precipitation": " 0.04G", "max_wind_speed": 18.1, "creation_time": "2019-05-23 10:32:11.027974", "air_temperature": 28}
# Message published successfully.
# {"location": {"coordinates": [-37.0046, 141.8047], "type": "Point"}, "sender_id": "event", "relative_humidity": 41.4, "topic": "climate", "windspeed_knots": 6.9, "precipitation": " 0.00G", "max_wind_speed": 8.9, "creation_time": "2019-05-23 10:32:16.061222", "air_temperature": 10}
# Message published successfully.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-cda3b2632906> in <module>()
#      26     publish_message(kafka_producer, 'climate', key, json.dumps(climate_dict))
#      27
# ---> 28     time.sleep(5)  #wait 5 seconds
#      29
#
# KeyboardInterrupt:

# %%
if kafka_producer is not None:
    kafka_producer.close()
